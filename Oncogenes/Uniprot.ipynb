# %%
import pandas as pd

# %%
fh = pd.read_table("C:/Users/jtso/Downloads/uniprot--proto+oncogene-.tab", sep="\t")
fh.head()
# Out:
#     Entry   Entry name    Status  \
# 0  P00519   ABL1_HUMAN  reviewed
# 1  P42684   ABL2_HUMAN  reviewed
# 2  O96019  ACL6A_HUMAN  reviewed
# 3  P51825   AFF1_HUMAN  reviewed
# 4  Q9UHB7   AFF4_HUMAN  reviewed
#
#                                        Protein names  \
# 0  Tyrosine-protein kinase ABL1 (EC 2.7.10.2) (Ab...
# 1  Abelson tyrosine-protein kinase 2 (EC 2.7.10.2...
# 2  Actin-like protein 6A (53 kDa BRG1-associated ...
# 3  AF4/FMR2 family member 1 (ALL1-fused gene from...
# 4  AF4/FMR2 family member 4 (ALL1-fused gene from...
#
#                    Gene names              Organism  Length
# 0               ABL1 ABL JTK7  Homo sapiens (Human)    1130
# 1               ABL2 ABLL ARG  Homo sapiens (Human)    1182
# 2  ACTL6A BAF53 BAF53A INO80K  Homo sapiens (Human)     429
# 3     AFF1 AF4 FEL MLLT2 PBM1  Homo sapiens (Human)    1210
# 4    AFF4 AF5Q31 MCEF HSPC092  Homo sapiens (Human)    1163

# %%
genes = []
for idx,row in fh.iterrows():
    a = str(row["Gene names"]).split(" ")
    genes += a
    
genes
# Out:
# ['ABL1',
#  'ABL',
#  'JTK7',
#  'ABL2',
#  'ABLL',
#  'ARG',
#  'ACTL6A',
#  'BAF53',
#  'BAF53A',
#  'INO80K',
#  'AFF1',
#  'AF4',
#  'FEL',
#  'MLLT2',
#  'PBM1',
#  'AFF4',
#  'AF5Q31',
#  'MCEF',
#  'HSPC092',
#  'AGR2',
#  'AG2',
#  'UNQ515/PRO1030',
#  'AKAP13',
#  'BRX',
#  'HT31',
#  'LBC',
#  'AKIP1',
#  'BCA3',
#  'C11orf17',
#  'AKT1',
#  'PKB',
#  'RAC',
#  'AKT2',
#  'ALK',
#  'ARAF',
#  'ARAF1',
#  'PKS',
#  'PKS2',
#  'ARHGAP26',
#  'GRAF',
#  'KIAA0621',
#  'OPHN1L',
#  'ARHGEF12',
#  'KIAA0382',
#  'LARG',
#  'ARHGEF5',
#  'TIM',
#  'ASPSCR1',
#  'ASPL',
#  'RCC17',
#  'TUG',
#  'UBXD9',
#  'UBXN9',
#  'AURKA',
#  'AIK',
#  'AIRK1',
#  'ARK1',
#  'AURA',
#  'AYK1',
#  'BTAK',
#  'IAK1',
#  'STK15',
#  'STK6',
#  'AXL',
#  'UFO',
#  'BAD',
#  'BBC6',
#  'BCL2L8',
#  'BCAS3',
#  'BCAS4',
#  'BCL11A',
#  'CTIP1',
#  'EVI9',
#  'KIAA1809',
#  'ZNF856',
#  'BCL2',
#  'BCL3',
#  'BCL4',
#  'D19S37',
#  'BCL6',
#  'BCL5',
#  'LAZ3',
#  'ZBTB27',
#  'ZNF51',
#  'BCL9',
#  'BCR',
#  'BCR1',
#  'D22S11',
#  'BMI1',
#  'PCGF4',
#  'RNF51',
#  'BRAF',
#  'BRAF1',
#  'RAFB1',
#  'BRCC3',
#  'BRCC36',
#  'C6.1A',
#  'CXorf53',
#  'BRD8',
#  'SMAP',
#  'SMAP2',
#  'BRI3BP',
#  'KG19',
#  'BTG1',
#  'CARS',
#  'c-bas/has',
#  'CBFB',
#  'CBL',
#  'CBL2',
#  'RNF55',
#  'CBLB',
#  'RNF56',
#  'Nbla00127',
#  'C-CBL',
#  'CCDC6',
#  'D10S170',
#  'TST1',
#  'CCND1',
#  'BCL1',
#  'PRAD1',
#  'CCND2',
#  'CCND3',
#  'CCNL1',
#  'BM-001',
#  'UNQ530/PRO1073',
#  'CDKN1B',
#  'KIP1',
#  'CDT1',
#  'c-erbB',
#  'proto-oncogene',
#  'CMC4',
#  'C6.1B',
#  'MTCP1',
#  'MTCP1NB',
#  'CREB3L2',
#  'BBF2H7',
#  'CRK',
#  'CRKL',
#  'CSF1R',
#  'FMS',
#  'CSNK2A3',
#  'CSNK2A1P',
#  'CTTN',
#  'EMS1',
#  'DACH1',
#  'DACH',
#  'DCUN1D1',
#  'DCUN1L1',
#  'RP42',
#  'SCCRO',
#  'DDIT3',
#  'CHOP',
#  'CHOP10',
#  'GADD153',
#  'DDX6',
#  'HLR2',
#  'RCK',
#  'DEK',
#  'DMAP1',
#  'KIAA1425',
#  'DMBT1',
#  'GP340',
#  'DOCK4',
#  'KIAA0716',
#  'EGFR',
#  'ERBB',
#  'ERBB1',
#  'HER1',
#  'EIF4E',
#  'EIF4EL1',
#  'EIF4F',
#  'ELAC2',
#  'HPC2',
#  'ELF4',
#  'ELFR',
#  'MEF',
#  'ELL',
#  'C19orf17',
#  'ENTPD5',
#  'CD39L4',
#  'PCPH',
#  'EPC1',
#  'EPS15',
#  'AF1P',
#  'ERBB2',
#  'HER2',
#  'MLN19',
#  'NEU',
#  'NGL',
#  'ERBB3',
#  'HER3',
#  'ERBB4',
#  'HER4',
#  'ERG',
#  'ETS1',
#  'EWSR2',
#  'ETS2',
#  'ETV1',
#  'ER81',
#  'ETV6',
#  'TEL',
#  'TEL1',
#  'EVI2A',
#  'EVDA',
#  'EVI2',
#  'EVI2B',
#  'EVDB',
#  'EWSR1',
#  'EWS',
#  'FCGR2B',
#  'CD32',
#  'FCG2',
#  'IGFR2',
#  'FER',
#  'TYK3',
#  'FES',
#  'FPS',
#  'FES',
#  'FES',
#  'FGF3',
#  'INT2',
#  'FGF4',
#  'HST',
#  'HSTF1',
#  'KS3',
#  'FGF5',
#  'FGF6',
#  'HST2',
#  'HSTF2',
#  'FGFR1',
#  'BFGFR',
#  'CEK',
#  'FGFBR',
#  'FLG',
#  'FLT2',
#  'HBGFR',
#  'FGFR2',
#  'BEK',
#  'KGFR',
#  'KSAM',
#  'FGFR3',
#  'JTK4',
#  'FGR',
#  'SRC2',
#  'FLI1',
#  'FLT3',
#  'CD135',
#  'FLK2',
#  'STK1',
#  'FOS',
#  'G0S7',
#  'FOS',
#  'FOS',
#  'FOS',
#  'FOS',
#  'FOS',
#  'FOS',
#  'FOXO1',
#  'FKHR',
#  'FOXO1A',
#  'FOXO3',
#  'FKHRL1',
#  'FOXO3A',
#  'FOXO4',
#  'AFX',
#  'AFX1',
#  'MLLT7',
#  'FRAT1',
#  'FSTL3',
#  'FLRG',
#  'UNQ674/PRO1308',
#  'FUNDC2',
#  'HCBP6',
#  'DC44',
#  'HCC3',
#  'PD03104',
#  'FURIN',
#  'FUR',
#  'PACE',
#  'PCSK3',
#  'FUS',
#  'TLS',
#  'FYN',
#  'GAS7',
#  'KIAA0394',
#  'GFI1',
#  'ZNF163',
#  'GFI1B',
#  'GLI1',
#  'GLI',
#  'GMPS',
#  'GNAS',
#  'GNAS1',
#  'GSP',
#  'GNB2L1',
#  'HLC7',
#  'PIG21',
#  'HCC5',
#  'HCK',
#  'HEXB',
#  'HCC7',
#  'HLF',
#  'HMGA2',
#  'HMGIC',
#  'HOPX',
#  'HOD',
#  'HOP',
#  'LAGY',
#  'NECC1',
#  'OB1',
#  'HOXA9',
#  'HOX1G',
#  'HRAS',
#  'HRAS1',
#  'IL2',
#  'ING3',
#  'HSPC301',
#  'IRS4',
#  'JAK2',
#  'JAZF1',
#  'TIP27',
#  'ZNF802',
#  'JUN',
#  'JUNB',
#  'hCG_172481',
#  'KAT5',
#  'HTATIP',
#  'TIP60',
#  'KAT6A',
#  'MOZ',
#  'MYST3',
#  'RUNXBP2',
#  'ZNF220',
#  'KDSR',
#  'FVT1',
#  'SDR35C1',
#  'KIT',
#  'SCFR',
#  'KIT',
#  'KLF6',
#  'BCD1',
#  'COPEB',
#  'CPBP',
#  'ST12',
#  'KMT2A',
#  'ALL1',
#  'CXXC7',
#  'HRX',
#  'HTRX',
#  'MLL',
#  'MLL1',
#  'TRX1',
#  'KRAS',
#  'KRAS2',
#  'RASK2',
#  'LCK',
#  'LETMD1',
#  'LHX4',
#  'LITAF',
#  'PIG7',
#  'SIMPLE',
#  'LMO1',
#  'RBTN1',
#  'RHOM1',
#  'TTG1',
#  'LMO2',
#  'RBTN2',
#  'RBTNL1',
#  'RHOM2',
#  'TTG2',
#  'LYL1',
#  'BHLHA18',
#  'LYN',
#  'JTK8',
#  'MAF',
#  'MAF',
#  'MAFA',
#  'MAFB',
#  'KRML',
#  'MAP3K8',
#  'COT',
#  'ESTF',
#  'MAPK15',
#  'ERK7',
#  'ERK8',
#  'MAS1',
#  'MAS',
#  'MCF2',
#  'DBL',
#  'MCF2',
#  'MCF2',
#  'MCF2L',
#  'KIAA0362',
#  'MDM2',
#  'MDS2',
#  'MECOM',
#  'EVI1',
#  'MERTK',
#  'MER',
#  'MET',
#  'MGRA',
#  'MKL1',
#  'KIAA1438',
#  'MAL',
#  'MKRN2',
#  'RNF62',
#  'HSPC070',
#  'MLL/CBL',
#  'fusion',
#  'MLLT1',
#  'ENL',
#  'LTG19',
#  'YEATS1',
#  'MLLT10',
#  'AF10',
#  'MLLT11',
#  'AF1Q',
#  'MLLT3',
#  'AF9',
#  'YEATS3',
#  'MLLT4',
#  'AF6',
#  'MLLT6',
#  'AF17',
#  'MORF4L1',
#  'MRG15',
#  'FWP006',
#  'HSPC008',
#  'HSPC061',
#  'PP368',
#  'MORF4L2',
#  'KIAA0026',
#  'MRGX',
#  'MOS',
#  'MPL',
#  'TPOR',
#  'MRGBP',
#  'C20orf20',
#  'MRPS11',
#  'RPMS11',
#  'HCC2',
#  'MTCP1',
#  'C6.1B',
#  'MXI1',
#  'BHLHC11',
#  'MYB',
#  'MYC',
#  'BHLHE39',
#  'MYC',
#  'MYC',
#  'hCG_15917',
#  'MYC',
#  'MYC',
#  'MYC',
#  'MYCN',
#  'BHLHE37',
#  'NMYC',
#  'MYEOV',
#  'OCIM',
#  'MYH11',
#  'KIAA0866',
#  'NAE1',
#  'APPBP1',
#  'HPP1',
#  'NCKIPSD',
#  'AF3P21',
#  'SPIN90',
#  'NCOA1',
#  'BHLHE74',
#  'SRC1',
#  'NCOA4',
#  'ARA70',
#  'ELE1',
#  'RFG',
#  'NET1',
#  'ARHGEF8',
#  'NFKB2',
#  'LYT10',
#  'NFKBIB',
#  'IKBB',
#  'TRIP9',
#  'NGF',
#  'NGFB',
#  'NME2',
#  'NM23B',
#  'NOTCH4',
#  'INT3',
#  'NOV',
#  'CCN3',
#  'IGFBP9',
#  'NOVH',
#  'NPM1',
#  'NPM',
#  'NR4A3',
#  'CHN',
#  'CSMF',
#  'MINOR',
#  'NOR1',
#  'TEC',
#  'NRAS',
#  'HRAS1',
#  'NSD1',
#  'ARA267',
#  'KMT3B',
#  'NTRK1',
#  'MTC',
#  'TRK',
#  'TRKA',
#  'NUP214',
#  'CAIN',
#  'CAN',
#  'KIAA0023',
#  'OLIG2',
#  'BHLHB1',
#  'BHLHE19',
#  'PRKCBP2',
#  'RACK17',
#  'PAK7',
#  'KIAA1264',
#  'PAK5',
#  'PATZ1',
#  'PATZ',
#  'RIAZ',
#  'ZBTB19',
#  'ZNF278',
#  'ZSG',
#  'PAX3',
#  'HUP2',
#  'PAX5',
#  'PAX7',
#  'HUP1',
#  'PBX1',
#  'PRL',
#  'PBX2',
#  'G17',
#  'PBX3',
#  'PCM1',
#  'PDGFB',
#  'PDGF2',
#  'SIS',
#  'PDGFD',
#  'IEGF',
#  'SCDGFB',
#  'MSTP036',
#  'UNQ1899/PRO4345',
#  'PDGFRA',
#  'PDGFR2',
#  'RHEPDGFRA',
#  'PDGFRB',
#  'PDGFR',
#  'PDGFR1',
#  'PHB',
#  'PICALM',
#  'CALM',
#  'PIK3CA',
#  'PIK3R1',
#  'GRB1',
#  'PIM1',
#  'PIM2',
#  'PIM3',
#  'PIN1',
#  'PLAG1',
#  'PML',
#  'MYL',
#  'PP8675',
#  'RNF71',
#  'TRIM19',
#  'POU2AF1',
#  'OBF1',
#  'PRCC',
#  'TPRC',
#  'PRKCA',
#  'PKCA',
#  'PRKACA',
#  'PRKCI',
#  'DXS1179E',
#  'PSMD10',
#  'PTK2',
#  'FAK',
#  'FAK1',
#  'PTTG1',
#  'EAP1',
#  'PTTG',
#  'TUTR1',
#  'PTTG2',
#  'PTTG3P',
#  'PTTG3',
#  'RAB8A',
#  'MEL',
#  'RAB8',
#  'RAF1',
#  'RAF',
#  'RAF1',
#  'RAF1',
#  'RARA',
#  'NR1B1',
#  'RARB',
#  'HAP',
#  'NR1B2',
#  'RASA1',
#  'GAP',
#  'RASA',
#  'RB1',
#  'RBM15',
#  'OTT',
#  'OTT1',
#  'REL',
#  'RET',
#  'CDHF12',
#  'CDHR16',
#  'PTC',
#  'RET51',
#  'RET',
#  'hCG_22740',
#  'RET',
#  'hCG_22740',
#  'RET',
#  'hCG_22740',
#  'RET',
#  'RET',
#  'hCG_22740',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'RET',
#  'proto-oncogene',
#  'RET',
#  'RET/PTC2',
#  'RHOA',
#  'ARH12',
#  'ARHA',
#  'RHO12',
#  'RNF213',
#  'ALO17',
#  'C17orf27',
#  'KIAA1554',
#  'KIAA1618',
#  'MYSTR',
#  'ROS1',
#  'MCF3',
#  'ROS',
#  'ROS1',
#  'RPL10',
#  'DXS648E',
#  'QM',
#  'RRAS2',
#  'TC21',
#  'RUNX1',
#  'AML1',
#  'CBFA2',
#  'RUNX1T1',
#  'AML1T1',
#  'CBFA2T1',
#  'CDR',
#  'ETO',
#  'MTG8',
#  'ZMYND2',
#  'RUVBL1',
#  'INO80H',
#  'NMP238',
#  'TIP49',
#  'TIP49A',
#  'RUVBL2',
#  'INO80J',
#  'TIP48',
#  'TIP49B',
#  'CGI-46',
#  'SEC31A',
#  'KIAA0905',
#  'SEC31L1',
#  'HSPC275',
#  'HSPC334',
#  'SET',
#  'SH3BP1',
#  'SH3GL1',
#  'CNSA1',
#  'SH3D2B',
#  'SKI',
#  'SKIL',
#  'SNO',
#  'SPECC1',
#  'CYTSB',
#  'NSP5',
#  'SPI1',
#  'Spi-1',
#  'SRC',
#  'SRC1',
#  'SS18',
#  'SSXT',
#  'SYT',
#  'SSX1',
#  'SSX2',
#  'SSX2A;',
#  'SSX2B',
#  'STIL',
#  'SIL',
#  'STK3',
#  'KRS1',
#  'MST2',
#  'STYK1',
#  'NOK',
#  'SUZ12',
#  'CHET9',
#  'JJAZ1',
#  'KIAA0160',
#  'SYK',
#  'TAF15',
#  'RBP56',
#  'TAF2N',
#  'TAL1',
#  'BHLHA17',
#  'SCL',
#  'TCL5',
#  'TAL2',
#  'BHLHA19',
#  'TBC1D3',
#  'PRC17',
#  'TBC1D3A',
#  'TCF3',
#  'BHLHB21',
#  'E2A',
#  'ITF1',
#  'TCL1A',
#  'TCL1',
#  'TCL1B',
#  'TCL1',
#  'TCTA',
#  'TEF',
#  'KIAA1655',
#  'TFE3',
#  'BHLHE33',
#  'TFG',
#  'TFPT',
#  'INO80F',
#  'THRB',
#  'ERBA2',
#  'NR1A2',
#  'THR1',
#  'TLX1',
#  'HOX11',
#  'TCL3',
#  'TNFRSF17',
#  'BCM',
#  'BCMA',
#  'TOP1',
#  'TPM3',
#  'TPR',
#  'TRIM27',
#  'RFP',
#  'RNF76',
#  'TRIM37',
#  'KIAA0898',
#  'MUL',
#  'POB1',
#  'TTC23',
#  'HCC8',
#  'USP28',
#  'KIAA1515',
#  'USP4',
#  'UNP',
#  'UNPH',
#  'USP6',
#  'HRP1',
#  'TRE2',
#  'VAV1',
#  'VAV',
#  'VAV1',
#  'VAV1',
#  'VAV1',
#  'VAV2',
#  'VHL',
#  'WDR11',
#  'BRWD2',
#  'KIAA1351',
#  'WDR15',
#  'WHSC1',
#  'KIAA1090',
#  'MMSET',
#  'NSD2',
#  'TRX5',
#  'WHSC1L1',
#  'NSD3',
#  'DC28',
#  'WISP1',
#  'CCN4',
#  'WNT1',
#  'INT1',
#  'WNT10B',
#  'WNT12',
#  'WNT3',
#  'INT4',
#  'WNT5A',
#  'WWTR1',
#  'TAZ',
#  'YAP1',
#  'YAP65',
#  'YEATS4',
#  'GAS41',
#  'YES1',
#  'YES',
#  'ZBTB16',
#  'PLZF',
#  'ZNF145',
#  'ZBTB7A',
#  'FBI1',
#  'LRF',
#  'ZBTB7',
#  'ZNF857A',
#  'ZFYVE19',
#  'ANCHR',
#  'MPFYVE',
#  'ZNF320',
#  'ZNF521',
#  'EHZF',
#  'LIP3',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
fha = pd.read_table("C:/Users/jtso/My Documents/Cancer miRNA rewiring project/table4onc.txt", sep="\t")
fha.head()
# Out:
#   Genesymbol              miRNA              Cancertype Targetsiteclass
# 0      4-Mar   hsa-miR-1273g-3p                    Lung       Disrupted
# 1      4-Mar  hsa-miR-181a-2-3p                    Lung       Disrupted
# 2      4-Mar       hsa-miR-5092                    Lung       Disrupted
# 3      3-Sep       hsa-miR-3154  Small cell lung cancer       Disrupted
# 4      3-Sep       hsa-miR-4428  Small cell lung cancer         Created

# %%
fha.loc[[4,5]]
# Out:
#   Genesymbol           miRNA              Cancertype Targetsiteclass
# 4      3-Sep    hsa-miR-4428  Small cell lung cancer         Created
# 5    AADACL2  hsa-miR-497-3p                Melanoma       Disrupted

# %%
onc = pd.DataFrame(columns=("Genesymbol", "miRNA", "Cancertype", "Targetsiteclass"))
for idx,row in fha.iterrows():
    if row["Genesymbol"] in genes:
        onc.loc[idx] = fha.loc[idx]
        print row["Genesymbol"]
onc
# Out:
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# AKT1
# ARHGAP26
# ARHGAP26
# ARHGAP26
# ARHGAP26
# ARHGAP26
# ARHGAP26
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCAS3
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# BCR
# FLI1
# FLI1
# FLI1
# FLI1
# FLI1
# FLI1
# MYH11
# MYH11
# MYH11
# MYH11
# MYH11
# MYH11
# MYH11
# MYH11
# MYH11
# 112042       AFF4    hsa-miR-1225-3p
# 112043       AFF4    hsa-miR-3162-3p
# 112044       AFF4       hsa-miR-3943
# 112045       AFF4    hsa-miR-4640-3p
# 112133       KRAS        hsa-miR-329
# 112134       KRAS     hsa-miR-362-3p
# 112135       KRAS       hsa-miR-3941
# 112136       KRAS       hsa-miR-4775
# 112137       KRAS        hsa-miR-603
# 112138       KRAS        hsa-miR-329
# 112139       KRAS     hsa-miR-362-3p
# 112140       KRAS       hsa-miR-3941
# 112141       KRAS       hsa-miR-4775
# 112142       KRAS        hsa-miR-603
# 112304        PML       hsa-miR-3131
# 112305        PML       hsa-miR-3169
# 112306        PML       hsa-miR-4318
# 112307        PML        hsa-miR-611
# 112357       TAL1     hsa-miR-185-3p
# 112358       TAL1    hsa-miR-3675-5p
# 112359       TAL1       hsa-miR-4492
# 112360       TAL1       hsa-miR-4675
# 112361       TAL1        hsa-miR-762
#
#                                          Cancertype Targetsiteclass
# 82                                         Prostate       Disrupted
# 83                                         Prostate       Disrupted
# 84                                         Prostate       Disrupted
# 85                                         Prostate       Disrupted
# 86                                         Prostate       Disrupted
# 87                                         Prostate       Disrupted
# 88                                         Prostate       Disrupted
# 89                                         Prostate       Disrupted
# 90                                         Prostate       Disrupted
# 91                                         Prostate       Disrupted
# 92                                         Prostate       Disrupted
# 93                                         Prostate       Disrupted
# 94                                         Prostate       Disrupted
# 95                                         Prostate       Disrupted
# 96                                         Prostate       Disrupted
# 97                                         Prostate       Disrupted
# 98                                         Prostate       Disrupted
# 99                                         Prostate       Disrupted
# 100                                        Prostate       Disrupted
# 101                                        Prostate       Disrupted
# 102                                        Prostate       Disrupted
# 103                                        Prostate         Created
# 104                                        Prostate         Created
# 105                                        Prostate         Created
# 211                                        Prostate       Disrupted
# 212                                        Prostate       Disrupted
# 213                                        Prostate       Disrupted
# 214                                        Prostate       Disrupted
# 215                                        Prostate         Created
# 216                                        Prostate         Created
# ...                                             ...             ...
# 111835                        LiverCancer(RIKEN,JP)       Disrupted
# 111836                        LiverCancer(RIKEN,JP)         Created
# 111837                        LiverCancer(RIKEN,JP)         Created
# 111838                        LiverCancer(RIKEN,JP)         Created
# 111839                        LiverCancer(RIKEN,JP)         Created
# 111840                        LiverCancer(RIKEN,JP)       Disrupted
# 111903                        LiverCancer(RIKEN,JP)         Created
# 112042                        LiverCancer(RIKEN,JP)         Created
# 112043                        LiverCancer(RIKEN,JP)       Disrupted
# 112044                        LiverCancer(RIKEN,JP)         Created
# 112045                        LiverCancer(RIKEN,JP)       Disrupted
# 112133             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112134             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112135             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112136             BreastInvasiveCarcinoma(TCGA,US)         Created
# 112137             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112138             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112139             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112140             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112141             BreastInvasiveCarcinoma(TCGA,US)         Created
# 112142             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112304  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112305  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112306  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112307  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112357                                     Melanoma       Disrupted
# 112358                                     Melanoma       Disrupted
# 112359                                     Melanoma       Disrupted
# 112360                                     Melanoma       Disrupted
# 112361                                     Melanoma       Disrupted
#
# [3765 rows x 4 columns]

# %%
onc
# Out:
#        Genesymbol              miRNA  \
# 82           AKT1      hsa-miR-548ac
# 83           AKT1      hsa-miR-548ac
# 84           AKT1      hsa-miR-548ac
# 85           AKT1    hsa-miR-548h-3p
# 86           AKT1       hsa-miR-548z
# 87           AKT1    hsa-miR-548h-3p
# 88           AKT1       hsa-miR-548z
# 89           AKT1    hsa-miR-548h-3p
# 90           AKT1       hsa-miR-548z
# 91           AKT1    hsa-miR-548d-3p
# 92           AKT1    hsa-miR-548d-3p
# 93           AKT1    hsa-miR-548d-3p
# 94           AKT1      hsa-miR-548aa
# 95           AKT1   hsa-miR-548ap-3p
# 96           AKT1    hsa-miR-548t-3p
# 97           AKT1      hsa-miR-548aa
# 98           AKT1   hsa-miR-548ap-3p
# 99           AKT1    hsa-miR-548t-3p
# 100          AKT1      hsa-miR-548aa
# 101          AKT1   hsa-miR-548ap-3p
# 102          AKT1    hsa-miR-548t-3p
# 103          AKT1       hsa-miR-4422
# 104          AKT1       hsa-miR-4422
# 105          AKT1       hsa-miR-4422
# 211      ARHGAP26    hsa-miR-193b-5p
# 212      ARHGAP26    hsa-miR-193b-5p
# 213      ARHGAP26       hsa-miR-5096
# 214      ARHGAP26       hsa-miR-5096
# 215      ARHGAP26    hsa-miR-4787-5p
# 216      ARHGAP26    hsa-miR-4787-5p
# ...           ...                ...
# 111835       MXI1    hsa-miR-5002-3p
# 111836       MXI1     hsa-miR-515-3p
# 111837       MXI1    hsa-miR-519e-3p
# 111838       MXI1  hsa-miR-550a-3-5p
# 111839       MXI1    hsa-miR-550a-5p
# 111840       MXI1     hsa-miR-873-3p
# 111903       AFF4     hsa-miR-570-3p
# 112042       AFF4    hsa-miR-1225-3p
# 112043       AFF4    hsa-miR-3162-3p
# 112044       AFF4       hsa-miR-3943
# 112045       AFF4    hsa-miR-4640-3p
# 112133       KRAS        hsa-miR-329
# 112134       KRAS     hsa-miR-362-3p
# 112135       KRAS       hsa-miR-3941
# 112136       KRAS       hsa-miR-4775
# 112137       KRAS        hsa-miR-603
# 112138       KRAS        hsa-miR-329
# 112139       KRAS     hsa-miR-362-3p
# 112140       KRAS       hsa-miR-3941
# 112141       KRAS       hsa-miR-4775
# 112142       KRAS        hsa-miR-603
# 112304        PML       hsa-miR-3131
# 112305        PML       hsa-miR-3169
# 112306        PML       hsa-miR-4318
# 112307        PML        hsa-miR-611
# 112357       TAL1     hsa-miR-185-3p
# 112358       TAL1    hsa-miR-3675-5p
# 112359       TAL1       hsa-miR-4492
# 112360       TAL1       hsa-miR-4675
# 112361       TAL1        hsa-miR-762
#
#                                          Cancertype Targetsiteclass
# 82                                         Prostate       Disrupted
# 83                                         Prostate       Disrupted
# 84                                         Prostate       Disrupted
# 85                                         Prostate       Disrupted
# 86                                         Prostate       Disrupted
# 87                                         Prostate       Disrupted
# 88                                         Prostate       Disrupted
# 89                                         Prostate       Disrupted
# 90                                         Prostate       Disrupted
# 91                                         Prostate       Disrupted
# 92                                         Prostate       Disrupted
# 93                                         Prostate       Disrupted
# 94                                         Prostate       Disrupted
# 95                                         Prostate       Disrupted
# 96                                         Prostate       Disrupted
# 97                                         Prostate       Disrupted
# 98                                         Prostate       Disrupted
# 99                                         Prostate       Disrupted
# 100                                        Prostate       Disrupted
# 101                                        Prostate       Disrupted
# 102                                        Prostate       Disrupted
# 103                                        Prostate         Created
# 104                                        Prostate         Created
# 105                                        Prostate         Created
# 211                                        Prostate       Disrupted
# 212                                        Prostate       Disrupted
# 213                                        Prostate       Disrupted
# 214                                        Prostate       Disrupted
# 215                                        Prostate         Created
# 216                                        Prostate         Created
# ...                                             ...             ...
# 111835                        LiverCancer(RIKEN,JP)       Disrupted
# 111836                        LiverCancer(RIKEN,JP)         Created
# 111837                        LiverCancer(RIKEN,JP)         Created
# 111838                        LiverCancer(RIKEN,JP)         Created
# 111839                        LiverCancer(RIKEN,JP)         Created
# 111840                        LiverCancer(RIKEN,JP)       Disrupted
# 111903                        LiverCancer(RIKEN,JP)         Created
# 112042                        LiverCancer(RIKEN,JP)         Created
# 112043                        LiverCancer(RIKEN,JP)       Disrupted
# 112044                        LiverCancer(RIKEN,JP)         Created
# 112045                        LiverCancer(RIKEN,JP)       Disrupted
# 112133             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112134             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112135             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112136             BreastInvasiveCarcinoma(TCGA,US)         Created
# 112137             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112138             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112139             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112140             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112141             BreastInvasiveCarcinoma(TCGA,US)         Created
# 112142             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 112304  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112305  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112306  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112307  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 112357                                     Melanoma       Disrupted
# 112358                                     Melanoma       Disrupted
# 112359                                     Melanoma       Disrupted
# 112360                                     Melanoma       Disrupted
# 112361                                     Melanoma       Disrupted
#
# [3765 rows x 4 columns]

# %%
onc.to_csv("alloncs.txt", sep="\t")

# %%
len(onc)
# Out:
# 3765

# %%
import networkx as nx
import pandas as pd
from pylab import *
# %matplotlib inline
import numpy as np

# %%
G = nx.read_edgelist("C:/Users/jtso/My Documents/Cancer miRNA rewiring project/targetmirnas2.txt", delimiter="\t", create_using=nx.DiGraph())
G.remove_edge("miRNA", "Genesymbol")  # remove the header line

# %%
hey = 0
colors2 = []
miR = "hsa-miR-548c-3p"
targets = G.neighbors(miR)
miR3 = "hsa-miR-548aj-3p"
targets3 = G.neighbors(miR3)
miR4 = "hsa-miR-548aq-3p"
targets4 = G.neighbors(miR4)
miR5 = "hsa-miR-548z"
targets5 = G.neighbors(miR5)
mirs = [miR,miR3,miR4,miR5]
fhb = fha[fha["miRNA"].isin(mirs)]
g = G.subgraph(mirs + targets + targets3 + targets4 + targets5)
for j,k in g.edges():
    test1 = []
    hey += 1
    print hey, '\r',
    for idx,row in fhb.iterrows():
        if not row["miRNA"] == j:
            continue
        if not row["Genesymbol"] == k:
            continue
        if row["Genesymbol"] in test1:
            continue
        test1.append(row["Genesymbol"])
        if row["Targetsiteclass"] == "Created":
            colors2.append("g")
        else:
            colors2.append("r")
colors = ['orange' if n in mirs else 'b' for n in g.nodes()]
figure(figsize=(20,20))
nx.draw(g, node_color=colors, alpha=.2, with_labels=True, edge_color=colors2)

# %%
g.nodes()
# Out:
# [u'TRIM13',
#  u'IFFO2',
#  u'RNF10',
#  u'CPM',
#  u'CPD',
#  u'CHSY3',
#  u'NDUFB1',
#  u'AKT1',
#  u'PMP2',
#  'hsa-miR-548aj-3p',
#  u'SLC30A7',
#  u'SUPT3H',
#  u'MUC15',
#  u'CANX',
#  u'MSR1',
#  u'LOC401052',
#  u'PPP1R3C',
#  u'DGKB',
#  u'C10orf118',
#  u'SYS1',
#  u'NTRK2',
#  u'NAV2',
#  u'ZFAND6',
#  u'IRAK2',
#  u'RNF207',
#  u'FAM171A1',
#  u'C15orf38-AP3S2',
#  u'WDR5',
#  u'RAB5A',
#  u'CAPZA2',
#  u'PRRC2B',
#  u'ZNF680',
#  u'CTSC',
#  u'TDRD7',
#  u'CYB5B',
#  u'USP39',
#  u'OSBPL8',
#  u'SEC24A',
#  u'VKORC1L1',
#  u'QTRT1',
#  u'MDM2',
#  u'MTPAP',
#  u'MDM4',
#  u'SRP19',
#  u'SHMT1',
#  u'RGS13',
#  u'NFAT5',
#  u'ATXN7L1',
#  u'NIN',
#  u'CNN3',
#  u'PTMA',
#  u'STEAP4',
#  u'SNN',
#  u'CLEC2B',
#  u'AHR',
#  u'PGAM5',
#  u'GNG2',
#  u'AMMECR1',
#  u'TSR3',
#  u'PAK2',
#  u'ZBTB25',
#  u'PRR23A',
#  'hsa-miR-548c-3p',
#  u'ANO8',
#  u'SKAP2',
#  u'TRIM32',
#  u'RPL27A',
#  u'KDELC2',
#  u'DOCK7',
#  u'RIT1',
#  u'UBE2D1',
#  u'CRTC1',
#  u'SFXN2',
#  u'TANGO2',
#  u'IFNGR2',
#  u'C1orf21',
#  u'PNMA2',
#  u'WDR47',
#  u'NONO',
#  u'FAM175A',
#  u'EGR1',
#  u'HAUS3',
#  u'PPARGC1B',
#  u'SQLE',
#  u'EPPK1',
#  u'SYT13',
#  u'ZFP37',
#  u'NCOR1',
#  u'NEUROG2',
#  u'FNDC3B',
#  u'GRM1',
#  u'SPATA13',
#  u'RFPL4B',
#  u'MAL2',
#  u'UNC5D',
#  u'SNX30',
#  u'SGOL2',
#  u'ZNF587',
#  u'TMPRSS15',
#  u'FGF7',
#  u'SPICE1',
#  u'TRIM45',
#  u'ZNF28',
#  u'BCAR3',
#  u'GALNT3',
#  u'ABCG2',
#  u'GJA3',
#  u'CCDC132',
#  u'SH3BGRL2',
#  u'TAF8',
#  u'PDE6B',
#  u'WDFY3',
#  u'WDFY1',
#  u'SPOCK3',
#  u'GFPT1',
#  u'FAM134C',
#  u'ZNF701',
#  u'ZNF506',
#  u'MCPH1',
#  u'SOAT1',
#  u'FAM168B',
#  u'RECK',
#  u'AMPD3',
#  u'CDC42SE2',
#  u'CD300LG',
#  u'OLFM1',
#  u'GGCX',
#  u'UNC5CL',
#  u'FKTN',
#  u'ST6GAL2',
#  u'CBX5',
#  u'FECH',
#  u'KCMF1',
#  u'DNAJB9',
#  u'GUF1',
#  u'SPARC',
#  u'PYROXD1',
#  u'GRIA2',
#  u'IFI16',
#  u'CCPG1',
#  u'PPP1R12B',
#  u'PSMA5',
#  u'REEP3',
#  u'PBX1',
#  u'UBE2D4',
#  u'RASSF3',
#  u'POC5',
#  u'ITPRIPL2',
#  u'CEP44',
#  u'GSG1',
#  u'EGLN1',
#  u'GULP1',
#  u'KRTAP2-4',
#  u'CREBRF',
#  u'CDNF',
#  u'ALG11',
#  u'SAR1B',
#  u'RAD51C',
#  u'PDZRN3',
#  u'GLIPR1L2',
#  u'XKR4',
#  u'FAM65B',
#  u'KIF1C',
#  u'CCDC117',
#  u'ACOX1',
#  u'CLLU1OS',
#  u'AGPAT6',
#  u'ABCA5',
#  u'WDR17',
#  'hsa-miR-548z',
#  u'RNF144A',
#  u'CNTN6',
#  u'LENG8',
#  u'CCDC85A',
#  'hsa-miR-548aq-3p',
#  u'COLGALT1',
#  u'CYFIP1',
#  u'DESI1',
#  u'TMEM256',
#  u'TOMM22',
#  u'BCL11A',
#  u'SPECC1',
#  u'AP3S2',
#  u'NFYB',
#  u'RAB2B',
#  u'RRM2',
#  u'TRMT2B',
#  u'CPSF6',
#  u'RAD54B',
#  u'CALCOCO2',
#  u'UBQLN1',
#  u'NUP43',
#  u'GRIN3A',
#  u'GAL',
#  u'HOMER1',
#  u'VPS13D',
#  u'USP6NL',
#  u'NACC1',
#  u'EYA1',
#  u'RNMT',
#  u'DPY19L1',
#  u'KCND2',
#  u'CALHM2',
#  u'TMEM245',
#  u'LSM6',
#  u'NEIL2',
#  u'TSR2',
#  u'RRN3',
#  u'METTL21B',
#  u'WIPF2',
#  u'SSBP3',
#  u'TMEM41B',
#  u'FOXN2',
#  u'SASH1',
#  u'WFDC11',
#  u'SBNO1',
#  u'RGS7BP',
#  u'SLC7A14',
#  u'NAB1',
#  u'SRRM2',
#  u'CALU',
#  u'ROCK2',
#  u'FAM5C',
#  u'PURB',
#  u'ZNF468',
#  u'RND3',
#  u'PTPRB',
#  u'GRIN2D',
#  u'SH3BGR',
#  u'SPATA2',
#  u'HLA-DQA1',
#  u'C9orf91']

# %%
onc4 = pd.DataFrame(columns=("Genesymbol", "miRNA", "Cancertype", "Targetsiteclass"))
for idx,row in onc.iterrows():
    if row["miRNA"] in g.nodes():
        onc4.loc[idx] = onc.loc[idx]
        print row["Genesymbol"]
onc4
# Out:
# AKT1
# AKT1
# AKT1
# BCL11A
# BCL11A
# SPECC1
# SPECC1
# SPECC1
# MDM2
# BCL11A
# BCL11A
# PBX1
# PBX1
# PBX1
#       Genesymbol            miRNA               Cancertype Targetsiteclass
# 86          AKT1     hsa-miR-548z                 Prostate       Disrupted
# 88          AKT1     hsa-miR-548z                 Prostate       Disrupted
# 90          AKT1     hsa-miR-548z                 Prostate       Disrupted
# 4256      BCL11A  hsa-miR-548c-3p            Breast Cancer       Disrupted
# 4258      BCL11A  hsa-miR-548c-3p            Breast Cancer       Disrupted
# 42921     SPECC1  hsa-miR-548c-3p  ProstateCancer(OICR,CA)         Created
# 42922     SPECC1  hsa-miR-548c-3p  ProstateCancer(OICR,CA)         Created
# 42923     SPECC1  hsa-miR-548c-3p  ProstateCancer(OICR,CA)         Created
# 54386       MDM2  hsa-miR-548c-3p  ProstateCancer(OICR,CA)         Created
# 69081     BCL11A     hsa-miR-548z      LiverCancer(NCC,JP)         Created
# 75179     BCL11A  hsa-miR-548c-3p      LiverCancer(NCC,JP)       Disrupted
# 85021       PBX1     hsa-miR-548z    LiverCancer(RIKEN,JP)       Disrupted
# 85023       PBX1     hsa-miR-548z    LiverCancer(RIKEN,JP)       Disrupted
# 85025       PBX1     hsa-miR-548z    LiverCancer(RIKEN,JP)       Disrupted

# %%
pgenes = []
for idx,row in onc4.iterrows():
    if row["Genesymbol"] in pgenes:
        continue
    pgenes.append(row["Genesymbol"])
    
pgenes
# Out:
# ['AKT1', 'BCL11A', 'SPECC1', 'MDM2', 'PBX1']

# %%
hey = 0
colors2 = []
colors = []
shape = []
miR = "hsa-miR-548c-3p"
targets = G.neighbors(miR)
miR3 = "hsa-miR-548aj-3p"
targets3 = G.neighbors(miR3)
miR4 = "hsa-miR-548aq-3p"
targets4 = G.neighbors(miR4)
miR5 = "hsa-miR-548z"
targets5 = G.neighbors(miR5)
mirs = [miR,miR3,miR4,miR5]
fhb = fha[fha["miRNA"].isin(mirs)]
g = G.subgraph(mirs + targets + targets3 + targets4 + targets5)
pos = nx.spring_layout(g)
for j,k in g.edges():
    test1 = []
    hey += 1
    print hey, '\r',
    for idx,row in fhb.iterrows():
        if not row["miRNA"] == j:
            continue
        if not row["Genesymbol"] == k:
            continue
        if row["Genesymbol"] in test1:
            continue
        test1.append(row["Genesymbol"])
        if row["Targetsiteclass"] == "Created":
            colors2.append("g")
        else:
            colors2.append("r")

ugenes= ['SPECC1', 'MDM2']
fgenes= ['AKT1', 'BCL11A', 'PBX1']
rgenes = []
for a in g.nodes():
    if not a in (mirs + fgenes + ugenes):
        rgenes.append(a)
d={}
for i in mirs:
    d[i] = i

for a in pgenes:
    d[a] = a
figure(figsize=(20,20))
nx.draw_networkx_nodes(g, pos, nodelist=rgenes, node_color = "b", alpha = .3, node_shape = "o")
nx.draw_networkx_nodes(g, pos, nodelist= mirs, node_color = "orange", alpha=.3, node_shape = "^")
nx.draw_networkx_nodes(g, pos, nodelist= fgenes, node_color = "lime", alpha=.3, node_shape = "s")
nx.draw_networkx_nodes(g, pos, nodelist = ugenes, node_color = "fuchsia", alpha=.3, node_shape = "s")
nx.draw_networkx_edges(g, pos, edge_color = colors2, alpha = .4)
nx.draw_networkx_labels(g, pos, labels = d)
# Out:
# {'AKT1': <matplotlib.text.Text at 0x12391a90>,
#  'BCL11A': <matplotlib.text.Text at 0x12391610>,
#  'MDM2': <matplotlib.text.Text at 0x12397190>,
#  'PBX1': <matplotlib.text.Text at 0x123973d0>,
#  'SPECC1': <matplotlib.text.Text at 0x12391850>,
#  'hsa-miR-548aj-3p': <matplotlib.text.Text at 0x12391f30>,
#  'hsa-miR-548aq-3p': <matplotlib.text.Text at 0x123910b0>,
#  'hsa-miR-548c-3p': <matplotlib.text.Text at 0x123913b0>,
#  'hsa-miR-548z': <matplotlib.text.Text at 0x12391cd0>}

# %%
mirs + pgenes
# Out:
# ['hsa-miR-548c-3p',
#  'hsa-miR-548aj-3p',
#  'hsa-miR-548aq-3p',
#  'hsa-miR-548z',
#  'AKT1',
#  'BCL11A',
#  'SPECC1',
#  'MDM2',
#  'PBX1']

# %%
mirs
# Out:
# ['hsa-miR-548c-3p', 'hsa-miR-548aj-3p', 'hsa-miR-548aq-3p', 'hsa-miR-548z']

# %%
pgenes
# Out:
# ['AKT1', 'BCL11A', 'SPECC1', 'MDM2', 'PBX1']

# %%
ao = pd.read_table("C:/Users/jtso/My Documents/GitHub/tcga-mir-rewire/Oncogenes/alloncs.txt", sep="\t")
ao
# Out:
#      Genesymbol              miRNA  \
# 0          AKT1      hsa-miR-548ac
# 1          AKT1      hsa-miR-548ac
# 2          AKT1      hsa-miR-548ac
# 3          AKT1    hsa-miR-548h-3p
# 4          AKT1       hsa-miR-548z
# 5          AKT1    hsa-miR-548h-3p
# 6          AKT1       hsa-miR-548z
# 7          AKT1    hsa-miR-548h-3p
# 8          AKT1       hsa-miR-548z
# 9          AKT1    hsa-miR-548d-3p
# 10         AKT1    hsa-miR-548d-3p
# 11         AKT1    hsa-miR-548d-3p
# 12         AKT1      hsa-miR-548aa
# 13         AKT1   hsa-miR-548ap-3p
# 14         AKT1    hsa-miR-548t-3p
# 15         AKT1      hsa-miR-548aa
# 16         AKT1   hsa-miR-548ap-3p
# 17         AKT1    hsa-miR-548t-3p
# 18         AKT1      hsa-miR-548aa
# 19         AKT1   hsa-miR-548ap-3p
# 20         AKT1    hsa-miR-548t-3p
# 21         AKT1       hsa-miR-4422
# 22         AKT1       hsa-miR-4422
# 23         AKT1       hsa-miR-4422
# 24     ARHGAP26    hsa-miR-193b-5p
# 25     ARHGAP26    hsa-miR-193b-5p
# 26     ARHGAP26       hsa-miR-5096
# 27     ARHGAP26       hsa-miR-5096
# 28     ARHGAP26    hsa-miR-4787-5p
# 29     ARHGAP26    hsa-miR-4787-5p
# ...         ...                ...
# 3735       MXI1    hsa-miR-5002-3p
# 3736       MXI1     hsa-miR-515-3p
# 3737       MXI1    hsa-miR-519e-3p
# 3738       MXI1  hsa-miR-550a-3-5p
# 3739       MXI1    hsa-miR-550a-5p
# 3740       MXI1     hsa-miR-873-3p
# 3741       AFF4     hsa-miR-570-3p
# 3742       AFF4    hsa-miR-1225-3p
# 3743       AFF4    hsa-miR-3162-3p
# 3744       AFF4       hsa-miR-3943
# 3745       AFF4    hsa-miR-4640-3p
# 3746       KRAS        hsa-miR-329
# 3747       KRAS     hsa-miR-362-3p
# 3748       KRAS       hsa-miR-3941
# 3749       KRAS       hsa-miR-4775
# 3750       KRAS        hsa-miR-603
# 3751       KRAS        hsa-miR-329
# 3752       KRAS     hsa-miR-362-3p
# 3753       KRAS       hsa-miR-3941
# 3754       KRAS       hsa-miR-4775
# 3755       KRAS        hsa-miR-603
# 3756        PML       hsa-miR-3131
# 3757        PML       hsa-miR-3169
# 3758        PML       hsa-miR-4318
# 3759        PML        hsa-miR-611
# 3760       TAL1     hsa-miR-185-3p
# 3761       TAL1    hsa-miR-3675-5p
# 3762       TAL1       hsa-miR-4492
# 3763       TAL1       hsa-miR-4675
# 3764       TAL1        hsa-miR-762
#
#                                        Cancertype Targetsiteclass
# 0                                        Prostate       Disrupted
# 1                                        Prostate       Disrupted
# 2                                        Prostate       Disrupted
# 3                                        Prostate       Disrupted
# 4                                        Prostate       Disrupted
# 5                                        Prostate       Disrupted
# 6                                        Prostate       Disrupted
# 7                                        Prostate       Disrupted
# 8                                        Prostate       Disrupted
# 9                                        Prostate       Disrupted
# 10                                       Prostate       Disrupted
# 11                                       Prostate       Disrupted
# 12                                       Prostate       Disrupted
# 13                                       Prostate       Disrupted
# 14                                       Prostate       Disrupted
# 15                                       Prostate       Disrupted
# 16                                       Prostate       Disrupted
# 17                                       Prostate       Disrupted
# 18                                       Prostate       Disrupted
# 19                                       Prostate       Disrupted
# 20                                       Prostate       Disrupted
# 21                                       Prostate         Created
# 22                                       Prostate         Created
# 23                                       Prostate         Created
# 24                                       Prostate       Disrupted
# 25                                       Prostate       Disrupted
# 26                                       Prostate       Disrupted
# 27                                       Prostate       Disrupted
# 28                                       Prostate         Created
# 29                                       Prostate         Created
# ...                                           ...             ...
# 3735                        LiverCancer(RIKEN,JP)       Disrupted
# 3736                        LiverCancer(RIKEN,JP)         Created
# 3737                        LiverCancer(RIKEN,JP)         Created
# 3738                        LiverCancer(RIKEN,JP)         Created
# 3739                        LiverCancer(RIKEN,JP)         Created
# 3740                        LiverCancer(RIKEN,JP)       Disrupted
# 3741                        LiverCancer(RIKEN,JP)         Created
# 3742                        LiverCancer(RIKEN,JP)         Created
# 3743                        LiverCancer(RIKEN,JP)       Disrupted
# 3744                        LiverCancer(RIKEN,JP)         Created
# 3745                        LiverCancer(RIKEN,JP)       Disrupted
# 3746             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3747             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3748             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3749             BreastInvasiveCarcinoma(TCGA,US)         Created
# 3750             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3751             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3752             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3753             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3754             BreastInvasiveCarcinoma(TCGA,US)         Created
# 3755             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3756  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3757  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3758  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3759  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3760                                     Melanoma       Disrupted
# 3761                                     Melanoma       Disrupted
# 3762                                     Melanoma       Disrupted
# 3763                                     Melanoma       Disrupted
# 3764                                     Melanoma       Disrupted
#
# [3765 rows x 4 columns]

# %%
len(ao)
# Out:
# 3765

# %%
ao2 = ao[ao["Targetsiteclass"] == "Disrupted"]

# %%
len(ao2)
# Out:
# 1847

# %%
aond = ao2.drop_duplicates()

# %%
len(aond)
# Out:
# 779

# %%
aond
# Out:
#      Genesymbol             miRNA  \
# 0          AKT1     hsa-miR-548ac
# 3          AKT1   hsa-miR-548h-3p
# 4          AKT1      hsa-miR-548z
# 9          AKT1   hsa-miR-548d-3p
# 12         AKT1     hsa-miR-548aa
# 13         AKT1  hsa-miR-548ap-3p
# 14         AKT1   hsa-miR-548t-3p
# 24     ARHGAP26   hsa-miR-193b-5p
# 26     ARHGAP26      hsa-miR-5096
# 30        BCAS3    hsa-miR-338-3p
# 34        BCAS3      hsa-miR-5193
# 36        BCAS3   hsa-miR-4691-5p
# 40        BCAS3    hsa-miR-766-3p
# 50          BCR       hsa-miR-612
# 52          BCR   hsa-miR-1285-3p
# 53          BCR   hsa-miR-3187-5p
# 54          BCR      hsa-miR-5189
# 68         FLI1    hsa-miR-20a-3p
# 74        MYH11   hsa-miR-4649-3p
# 94         PAX7      hsa-miR-4286
# 95        RAB8A   hsa-miR-4701-3p
# 96        RAB8A      hsa-miR-1262
# 99       ZNF320     hsa-miR-5692b
# 100      ZNF320     hsa-miR-5692c
# 106        AFF4      hsa-miR-4257
# 108        AFF4    hsa-miR-361-5p
# 109        AFF4   hsa-miR-2115-3p
# 111         AXL   hsa-miR-3065-3p
# 115      BCL11A   hsa-miR-548c-3p
# 119        CRKL      hsa-miR-4656
# ...         ...               ...
# 3678       ELF4   hsa-miR-4665-5p
# 3679       ELF4   hsa-miR-4667-5p
# 3680       ELF4   hsa-miR-4697-5p
# 3681       ELF4       hsa-miR-637
# 3693       MDM2      hsa-miR-1290
# 3694       MDM2    hsa-miR-541-5p
# 3695       TCF3      hsa-miR-1243
# 3696       TCF3      hsa-miR-3148
# 3697       TCF3      hsa-miR-3654
# 3698       TCF3    hsa-miR-875-3p
# 3699      PLAG1      hsa-miR-3148
# 3700      PLAG1   hsa-miR-3688-3p
# 3705       NET1      hsa-miR-3169
# 3707        PML      hsa-miR-3131
# 3708        PML      hsa-miR-3169
# 3709        PML      hsa-miR-4318
# 3710        PML       hsa-miR-611
# 3715       MXI1   hsa-miR-5002-3p
# 3720       MXI1    hsa-miR-873-3p
# 3743       AFF4   hsa-miR-3162-3p
# 3745       AFF4   hsa-miR-4640-3p
# 3746       KRAS       hsa-miR-329
# 3747       KRAS    hsa-miR-362-3p
# 3748       KRAS      hsa-miR-3941
# 3750       KRAS       hsa-miR-603
# 3760       TAL1    hsa-miR-185-3p
# 3761       TAL1   hsa-miR-3675-5p
# 3762       TAL1      hsa-miR-4492
# 3763       TAL1      hsa-miR-4675
# 3764       TAL1       hsa-miR-762
#
#                                        Cancertype Targetsiteclass
# 0                                        Prostate       Disrupted
# 3                                        Prostate       Disrupted
# 4                                        Prostate       Disrupted
# 9                                        Prostate       Disrupted
# 12                                       Prostate       Disrupted
# 13                                       Prostate       Disrupted
# 14                                       Prostate       Disrupted
# 24                                       Prostate       Disrupted
# 26                                       Prostate       Disrupted
# 30                                       Melanoma       Disrupted
# 34                                       Melanoma       Disrupted
# 36                                       Melanoma       Disrupted
# 40                                       Melanoma       Disrupted
# 50                                       Melanoma       Disrupted
# 52                                       Melanoma       Disrupted
# 53                                       Melanoma       Disrupted
# 54                                       Melanoma       Disrupted
# 68                                           Lung       Disrupted
# 74                                       Prostate       Disrupted
# 94                                       Melanoma       Disrupted
# 95                                           Lung       Disrupted
# 96                                           Lung       Disrupted
# 99                                       Melanoma       Disrupted
# 100                                      Melanoma       Disrupted
# 106                                 Breast Cancer       Disrupted
# 108                                 Breast Cancer       Disrupted
# 109                                 Breast Cancer       Disrupted
# 111                                 Breast Cancer       Disrupted
# 115                                 Breast Cancer       Disrupted
# 119                                 Breast Cancer       Disrupted
# ...                                           ...             ...
# 3678                          LiverCancer(NCC,JP)       Disrupted
# 3679                          LiverCancer(NCC,JP)       Disrupted
# 3680                          LiverCancer(NCC,JP)       Disrupted
# 3681                          LiverCancer(NCC,JP)       Disrupted
# 3693                 ColonAdenocarcinoma(TCGA,US)       Disrupted
# 3694                 ColonAdenocarcinoma(TCGA,US)       Disrupted
# 3695                          LiverCancer(NCC,JP)       Disrupted
# 3696                          LiverCancer(NCC,JP)       Disrupted
# 3697                          LiverCancer(NCC,JP)       Disrupted
# 3698                          LiverCancer(NCC,JP)       Disrupted
# 3699                          LiverCancer(NCC,JP)       Disrupted
# 3700                          LiverCancer(NCC,JP)       Disrupted
# 3705                          LiverCancer(NCC,JP)       Disrupted
# 3707  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3708  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3709  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3710  UterineCorpusEndometrioidCarcinoma(TCGA,US)       Disrupted
# 3715                        LiverCancer(RIKEN,JP)       Disrupted
# 3720                        LiverCancer(RIKEN,JP)       Disrupted
# 3743                        LiverCancer(RIKEN,JP)       Disrupted
# 3745                        LiverCancer(RIKEN,JP)       Disrupted
# 3746             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3747             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3748             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3750             BreastInvasiveCarcinoma(TCGA,US)       Disrupted
# 3760                                     Melanoma       Disrupted
# 3761                                     Melanoma       Disrupted
# 3762                                     Melanoma       Disrupted
# 3763                                     Melanoma       Disrupted
# 3764                                     Melanoma       Disrupted
#
# [779 rows x 4 columns]

# %%
aond[["miRNA", "Genesymbol"]].to_csv("finaltrythis.txt", sep="\t")

# %%
K = nx.read_edgelist("C:/Users/jtso/My Documents/Cancer miRNA rewiring project/finaltrythis2.txt", delimiter="\t", create_using=nx.DiGraph())
K.remove_edge("Genesymbol", "miRNA")  # remove the header line

# %%
from collections import Counter
dd = {}
for idx,row in aond.iterrows():
    dd[row["Genesymbol"]] = []
for idx,row in aond.iterrows():
    if row["Cancertype"] in dd[row["Genesymbol"]]:
        continue
    dd[row["Genesymbol"]].append(row["Cancertype"])
dd
# Out:
# {'ABL1': ['LiverCancer(NCC,JP)'],
#  'ABL2': ['LiverCancer(RIKEN,JP)', 'ProstateCancer(OICR,CA)'],
#  'AFF1': ['LiverCancer(NCC,JP)'],
#  'AFF4': ['Breast Cancer', 'LiverCancer(RIKEN,JP)', 'LiverCancer(NCC,JP)'],
#  'AKAP13': ['LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)'],
#  'AKT1': ['Prostate', 'LiverCancer(NCC,JP)'],
#  'AKT2': ['Hepatocellular carcinoma',
#   'LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(NCC,JP)'],
#  'ARAF': ['LiverCancer(NCC,JP)'],
#  'ARHGAP26': ['Prostate', 'ProstateCancer(OICR,CA)'],
#  'AURKA': ['BreastCarcinoma(WTSI,UK)'],
#  'AXL': ['Breast Cancer'],
#  'BCAS3': ['Melanoma', 'LiverCancer(NCC,JP)'],
#  'BCAS4': ['LiverCancer(RIKEN,JP)'],
#  'BCL11A': ['Breast Cancer', 'LiverCancer(NCC,JP)'],
#  'BCL2': ['ProstateCancer(OICR,CA)'],
#  'BCL9': ['LiverCancer(NCC,JP)'],
#  'BCR': ['Melanoma'],
#  'BRD8': ['LiverCancer(RIKEN,JP)'],
#  'BRI3BP': ['LiverCancer(NCC,JP)'],
#  'BTG1': ['LiverCancer(RIKEN,JP)'],
#  'CBL': ['LiverCancer(RIKEN,JP)', 'ProstateCancer(OICR,CA)'],
#  'CCND2': ['LiverCancer(RIKEN,JP)'],
#  'CCNL1': ['LiverCancer(RIKEN,JP)'],
#  'CDKN1B': ['LiverCancer(NCC,JP)'],
#  'CREB3L2': ['LiverCancer(RIKEN,JP)'],
#  'CRK': ['LiverCancer(NCC,JP)'],
#  'CRKL': ['Breast Cancer',
#   'LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)',
#   'ProstateCancer(OICR,CA)'],
#  'DACH1': ['LiverCancer(RIKEN,JP)'],
#  'DEK': ['LiverCancer(NCC,JP)'],
#  'EGFR': ['Colorectal adenocarcinoma',
#   'LiverCancer(RIKEN,JP)',
#   'Leukemia/T-ALL'],
#  'ELF4': ['LiverCancer(NCC,JP)'],
#  'ELL': ['LiverCancer(NCC,JP)'],
#  'ENTPD5': ['LiverCancer(NCC,JP)'],
#  'EPS15': ['LiverCancer(RIKEN,JP)'],
#  'ERBB3': ['ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)'],
#  'ERBB4': ['Acute myeloid leukemia',
#   'Colorectal adenocarcinoma',
#   'LiverCancer(RIKEN,JP)'],
#  'ERG': ['LiverCancer(NCC,JP)', 'Hypodiploid_ALL'],
#  'ETV1': ['LiverCancer(RIKEN,JP)'],
#  'ETV6': ['LiverCancer(RIKEN,JP)'],
#  'FGF5': ['ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'FGFR1': ['Medulloblastoma',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)',
#   'Leukemia/T-ALL'],
#  'FGFR2': ['Colorectal adenocarcinoma',
#   'GastricCancer(CCGC,CN)',
#   'Leukemia/T-ALL'],
#  'FGFR3': ['Leukemia/T-ALL'],
#  'FLI1': ['Lung'],
#  'FLT3': ['Leukemia/T-ALL'],
#  'FOXO4': ['LiverCancer(NCC,JP)'],
#  'FURIN': ['LiverCancer(RIKEN,JP)'],
#  'GAS7': ['LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(NCC,JP)'],
#  'GFI1': ['LiverCancer(NCC,JP)'],
#  'GNAS': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'BladderUrothelialCarcinoma(TCGA,US)',
#   'LiverCancer(NCC,JP)'],
#  'HCK': ['LiverCancer(NCC,JP)'],
#  'HLF': ['LiverCancer(NCC,JP)'],
#  'HMGA2': ['LiverCancer(RIKEN,JP)'],
#  'HOPX': ['LiverCancer(NCC,JP)'],
#  'HRAS': ['LiverCancer(NCC,JP)', 'Leukemia/T-ALL'],
#  'ING3': ['LiverCancer(NCC,JP)'],
#  'JUNB': ['Breast Cancer'],
#  'KAT5': ['LiverCancer(RIKEN,JP)'],
#  'KAT6A': ['Colorectal adenocarcinoma',
#   'BreastCarcinoma(WTSI,UK)',
#   'Hypodiploid_ALL'],
#  'KDSR': ['ProstateCancer(OICR,CA)'],
#  'KIT': ['LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'KLF6': ['LiverCancer(RIKEN,JP)'],
#  'KRAS': ['ProstateCancer(OICR,CA)', 'BreastInvasiveCarcinoma(TCGA,US)'],
#  'LCK': ['Leukemia/T-ALL'],
#  'LITAF': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'ProstateCancer(OICR,CA)'],
#  'MAF': ['LiverCancer(RIKEN,JP)'],
#  'MAFA': ['LiverCancer(RIKEN,JP)'],
#  'MAL': ['T-cell ALL'],
#  'MCF2': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'MDM2': ['ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)',
#   'ColonAdenocarcinoma(TCGA,US)'],
#  'MECOM': ['LiverCancer(RIKEN,JP)'],
#  'MET': ['ProstateCancer(OICR,CA)'],
#  'MKRN2': ['LiverCancer(NCC,JP)'],
#  'MLL': ['LiverCancer(RIKEN,JP)'],
#  'MLLT4': ['ProstateCancer(OICR,CA)'],
#  'MLLT6': ['Colorectal adenocarcinoma', 'ProstateCancer(OICR,CA)'],
#  'MTCP1': ['LiverCancer(NCC,JP)'],
#  'MXI1': ['LiverCancer(RIKEN,JP)'],
#  'MYC': ['LiverCancer(NCC,JP)'],
#  'MYH11': ['Prostate'],
#  'NCKIPSD': ['LiverCancer(RIKEN,JP)'],
#  'NET1': ['LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(NCC,JP)'],
#  'NR4A3': ['LiverCancer(NCC,JP)',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'NRAS': ['ProstateCancer(OICR,CA)', 'Leukemia/T-ALL'],
#  'NSD1': ['Hypodiploid_ALL'],
#  'PATZ1': ['LiverCancer(RIKEN,JP)'],
#  'PAX3': ['Medulloblastoma',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)'],
#  'PAX7': ['Melanoma', 'LiverCancer(RIKEN,JP)'],
#  'PBX1': ['LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)',
#   'ProstateCancer(OICR,CA)',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'PBX3': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'PCM1': ['ProstateCancer(OICR,CA)'],
#  'PDGFB': ['BreastCarcinoma(WTSI,UK)'],
#  'PDGFD': ['LiverCancer(NCC,JP)'],
#  'PDGFRA': ['LiverCancer(NCC,JP)'],
#  'PDGFRB': ['LiverCancer(NCC,JP)'],
#  'PIK3R1': ['LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'PLAG1': ['LiverCancer(RIKEN,JP)', 'LiverCancer(NCC,JP)'],
#  'PML': ['ProstateCancer(OICR,CA)',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'PRKCA': ['LiverCancer(RIKEN,JP)', 'Hypodiploid_ALL'],
#  'RAB8A': ['Lung'],
#  'RAF1': ['LiverCancer(NCC,JP)', 'ColonAdenocarcinoma(TCGA,US)'],
#  'RARA': ['LiverCancer(NCC,JP)'],
#  'RARB': ['LiverCancer(RIKEN,JP)'],
#  'RASA1': ['Medulloblastoma'],
#  'RB1': ['Hypodiploid_ALL'],
#  'REL': ['ProstateCancer(OICR,CA)'],
#  'RET': ['Leukemia/T-ALL'],
#  'RNF213': ['Breast Cancer', 'ProstateCancer(OICR,CA)'],
#  'RUNX1': ['LiverCancer(RIKEN,JP)'],
#  'RUNX1T1': ['LiverCancer(RIKEN,JP)'],
#  'SEC31A': ['LiverCancer(NCC,JP)'],
#  'SMAP2': ['Colorectal adenocarcinoma',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)'],
#  'SPECC1': ['Colorectal adenocarcinoma',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(NCC,JP)'],
#  'SPI1': ['Hepatocellular carcinoma'],
#  'SRC': ['Medulloblastoma'],
#  'SS18': ['ProstateCancer(OICR,CA)'],
#  'STIL': ['ProstateCancer(OICR,CA)'],
#  'SUZ12': ['Colorectal adenocarcinoma'],
#  'SYK': ['LiverCancer(RIKEN,JP)', 'ProstateCancer(OICR,CA)'],
#  'TAL1': ['LiverCancer(RIKEN,JP)', 'Melanoma'],
#  'TCF3': ['LiverCancer(NCC,JP)'],
#  'TCL1B': ['LiverCancer(NCC,JP)'],
#  'TCTA': ['Breast Cancer', 'ProstateCancer(OICR,CA)'],
#  'THRB': ['LiverCancer(RIKEN,JP)'],
#  'TOP1': ['LiverCancer(RIKEN,JP)'],
#  'TPM3': ['LiverCancer(RIKEN,JP)', 'BladderUrothelialCarcinoma(TCGA,US)'],
#  'TPR': ['Hepatocellular carcinoma'],
#  'TTC23': ['LiverCancer(RIKEN,JP)'],
#  'USP28': ['ProstateCancer(OICR,CA)'],
#  'USP4': ['LiverCancer(RIKEN,JP)', 'ProstateCancer(OICR,CA)'],
#  'VAV2': ['LiverCancer(NCC,JP)'],
#  'VHL': ['LiverCancer(NCC,JP)', 'Leukemia/T-ALL', 'Lung'],
#  'WDR11': ['LiverCancer(NCC,JP)'],
#  'WHSC1': ['ColonAdenocarcinoma(TCGA,US)',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(NCC,JP)'],
#  'WISP1': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'WNT1': ['LiverCancer(RIKEN,JP)'],
#  'WNT5A': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)', 'Hypodiploid_ALL'],
#  'WWTR1': ['LiverCancer(NCC,JP)'],
#  'ZFYVE19': ['Colorectal adenocarcinoma'],
#  'ZNF320': ['Melanoma',
#   'LiverCancer(NCC,JP)',
#   'LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)']}

# %%
for a,b in dd.items():
    dd[a] = len(dd[a])
    
dd
# Out:
# {'ABL1': 1,
#  'ABL2': 2,
#  'AFF1': 1,
#  'AFF4': 3,
#  'AKAP13': 2,
#  'AKT1': 2,
#  'AKT2': 4,
#  'ARAF': 1,
#  'ARHGAP26': 2,
#  'AURKA': 1,
#  'AXL': 1,
#  'BCAS3': 2,
#  'BCAS4': 1,
#  'BCL11A': 2,
#  'BCL2': 1,
#  'BCL9': 1,
#  'BCR': 1,
#  'BRD8': 1,
#  'BRI3BP': 1,
#  'BTG1': 1,
#  'CBL': 2,
#  'CCND2': 1,
#  'CCNL1': 1,
#  'CDKN1B': 1,
#  'CREB3L2': 1,
#  'CRK': 1,
#  'CRKL': 4,
#  'DACH1': 1,
#  'DEK': 1,
#  'EGFR': 3,
#  'ELF4': 1,
#  'ELL': 1,
#  'ENTPD5': 1,
#  'EPS15': 1,
#  'ERBB3': 3,
#  'ERBB4': 3,
#  'ERG': 2,
#  'ETV1': 1,
#  'ETV6': 1,
#  'FGF5': 3,
#  'FGFR1': 5,
#  'FGFR2': 3,
#  'FGFR3': 1,
#  'FLI1': 1,
#  'FLT3': 1,
#  'FOXO4': 1,
#  'FURIN': 1,
#  'GAS7': 3,
#  'GFI1': 1,
#  'GNAS': 3,
#  'HCK': 1,
#  'HLF': 1,
#  'HMGA2': 1,
#  'HOPX': 1,
#  'HRAS': 2,
#  'ING3': 1,
#  'JUNB': 1,
#  'KAT5': 1,
#  'KAT6A': 3,
#  'KDSR': 1,
#  'KIT': 2,
#  'KLF6': 1,
#  'KRAS': 2,
#  'LCK': 1,
#  'LITAF': 2,
#  'MAF': 1,
#  'MAFA': 1,
#  'MAL': 1,
#  'MCF2': 1,
#  'MDM2': 3,
#  'MECOM': 1,
#  'MET': 1,
#  'MKRN2': 1,
#  'MLL': 1,
#  'MLLT4': 1,
#  'MLLT6': 2,
#  'MTCP1': 1,
#  'MXI1': 1,
#  'MYC': 1,
#  'MYH11': 1,
#  'NCKIPSD': 1,
#  'NET1': 3,
#  'NR4A3': 2,
#  'NRAS': 2,
#  'NSD1': 1,
#  'PATZ1': 1,
#  'PAX3': 4,
#  'PAX7': 2,
#  'PBX1': 4,
#  'PBX3': 1,
#  'PCM1': 1,
#  'PDGFB': 1,
#  'PDGFD': 1,
#  'PDGFRA': 1,
#  'PDGFRB': 1,
#  'PIK3R1': 3,
#  'PLAG1': 2,
#  'PML': 2,
#  'PRKCA': 2,
#  'RAB8A': 1,
#  'RAF1': 2,
#  'RARA': 1,
#  'RARB': 1,
#  'RASA1': 1,
#  'RB1': 1,
#  'REL': 1,
#  'RET': 1,
#  'RNF213': 2,
#  'RUNX1': 1,
#  'RUNX1T1': 1,
#  'SEC31A': 1,
#  'SMAP2': 3,
#  'SPECC1': 3,
#  'SPI1': 1,
#  'SRC': 1,
#  'SS18': 1,
#  'STIL': 1,
#  'SUZ12': 1,
#  'SYK': 2,
#  'TAL1': 2,
#  'TCF3': 1,
#  'TCL1B': 1,
#  'TCTA': 2,
#  'THRB': 1,
#  'TOP1': 1,
#  'TPM3': 2,
#  'TPR': 1,
#  'TTC23': 1,
#  'USP28': 1,
#  'USP4': 2,
#  'VAV2': 1,
#  'VHL': 3,
#  'WDR11': 1,
#  'WHSC1': 3,
#  'WISP1': 1,
#  'WNT1': 1,
#  'WNT5A': 2,
#  'WWTR1': 1,
#  'ZFYVE19': 1,
#  'ZNF320': 4}

# %%
import operator
sorted_dd = sorted(dd.items(), key=operator.itemgetter(1))

# %%
sorted_dd
# Out:
# [('WISP1', 1),
#  ('BRI3BP', 1),
#  ('PDGFRB', 1),
#  ('MCF2', 1),
#  ('ARAF', 1),
#  ('AFF1', 1),
#  ('USP28', 1),
#  ('MAFA', 1),
#  ('AXL', 1),
#  ('FURIN', 1),
#  ('RARA', 1),
#  ('RARB', 1),
#  ('THRB', 1),
#  ('MYC', 1),
#  ('CCNL1', 1),
#  ('ENTPD5', 1),
#  ('NCKIPSD', 1),
#  ('FLI1', 1),
#  ('BRD8', 1),
#  ('TPR', 1),
#  ('PATZ1', 1),
#  ('FGFR3', 1),
#  ('CCND2', 1),
#  ('KAT5', 1),
#  ('RUNX1', 1),
#  ('MAF', 1),
#  ('MAL', 1),
#  ('PCM1', 1),
#  ('DEK', 1),
#  ('CRK', 1),
#  ('ZFYVE19', 1),
#  ('STIL', 1),
#  ('MTCP1', 1),
#  ('FLT3', 1),
#  ('TCF3', 1),
#  ('SPI1', 1),
#  ('HCK', 1),
#  ('ING3', 1),
#  ('ETV1', 1),
#  ('KDSR', 1),
#  ('HOPX', 1),
#  ('ETV6', 1),
#  ('VAV2', 1),
#  ('TOP1', 1),
#  ('NSD1', 1),
#  ('HLF', 1),
#  ('LCK', 1),
#  ('MYH11', 1),
#  ('PDGFRA', 1),
#  ('RET', 1),
#  ('MKRN2', 1),
#  ('REL', 1),
#  ('ABL1', 1),
#  ('BCAS4', 1),
#  ('BCR', 1),
#  ('RAB8A', 1),
#  ('BTG1', 1),
#  ('MECOM', 1),
#  ('PBX3', 1),
#  ('CDKN1B', 1),
#  ('TTC23', 1),
#  ('SRC', 1),
#  ('ELL', 1),
#  ('HMGA2', 1),
#  ('SS18', 1),
#  ('WWTR1', 1),
#  ('WNT1', 1),
#  ('MET', 1),
#  ('WDR11', 1),
#  ('JUNB', 1),
#  ('RUNX1T1', 1),
#  ('FOXO4', 1),
#  ('ELF4', 1),
#  ('SEC31A', 1),
#  ('EPS15', 1),
#  ('MLLT4', 1),
#  ('RB1', 1),
#  ('KLF6', 1),
#  ('AURKA', 1),
#  ('SUZ12', 1),
#  ('PDGFB', 1),
#  ('PDGFD', 1),
#  ('MLL', 1),
#  ('DACH1', 1),
#  ('RASA1', 1),
#  ('TCL1B', 1),
#  ('GFI1', 1),
#  ('MXI1', 1),
#  ('CREB3L2', 1),
#  ('BCL9', 1),
#  ('BCL2', 1),
#  ('AKT1', 2),
#  ('ARHGAP26', 2),
#  ('KRAS', 2),
#  ('USP4', 2),
#  ('SYK', 2),
#  ('KIT', 2),
#  ('TCTA', 2),
#  ('LITAF', 2),
#  ('HRAS', 2),
#  ('PAX7', 2),
#  ('RNF213', 2),
#  ('WNT5A', 2),
#  ('AKAP13', 2),
#  ('ABL2', 2),
#  ('RAF1', 2),
#  ('BCAS3', 2),
#  ('TPM3', 2),
#  ('PML', 2),
#  ('TAL1', 2),
#  ('BCL11A', 2),
#  ('ERG', 2),
#  ('CBL', 2),
#  ('MLLT6', 2),
#  ('NRAS', 2),
#  ('PLAG1', 2),
#  ('PRKCA', 2),
#  ('NR4A3', 2),
#  ('SMAP2', 3),
#  ('ERBB3', 3),
#  ('ERBB4', 3),
#  ('MDM2', 3),
#  ('FGFR2', 3),
#  ('WHSC1', 3),
#  ('AFF4', 3),
#  ('PIK3R1', 3),
#  ('FGF5', 3),
#  ('GAS7', 3),
#  ('EGFR', 3),
#  ('GNAS', 3),
#  ('SPECC1', 3),
#  ('VHL', 3),
#  ('NET1', 3),
#  ('KAT6A', 3),
#  ('CRKL', 4),
#  ('AKT2', 4),
#  ('PAX3', 4),
#  ('ZNF320', 4),
#  ('PBX1', 4),
#  ('FGFR1', 5)]

# %%
genes= []
targets=[]
for idx,row in aond.iterrows():
    if dd[row["Genesymbol"]] >= 3:
        genes.append(row["Genesymbol"])
        targets += K.neighbors(row["Genesymbol"])
k = K.subgraph(genes + targets)
colors = ['b' if n in genes else 'r' for n in k.nodes()]
figure(figsize=(50,50))
nx.draw(k, node_color=colors, alpha=.4, with_labels=True)

# %%
aond[aond["Genesymbol"] == "FGFR1"]
# Out:
#      Genesymbol             miRNA               Cancertype Targetsiteclass
# 325       FGFR1    hsa-miR-330-3p          Medulloblastoma       Disrupted
# 1512      FGFR1   hsa-miR-130a-3p  ProstateCancer(OICR,CA)       Disrupted
# 1513      FGFR1   hsa-miR-130b-3p  ProstateCancer(OICR,CA)       Disrupted
# 1515      FGFR1   hsa-miR-301a-3p  ProstateCancer(OICR,CA)       Disrupted
# 1516      FGFR1      hsa-miR-301b  ProstateCancer(OICR,CA)       Disrupted
# 2160      FGFR1      hsa-miR-4295  ProstateCancer(OICR,CA)       Disrupted
# 2161      FGFR1    hsa-miR-652-3p  ProstateCancer(OICR,CA)       Disrupted
# 2297      FGFR1      hsa-miR-3666  ProstateCancer(OICR,CA)       Disrupted
# 2335      FGFR1    hsa-miR-454-3p  ProstateCancer(OICR,CA)       Disrupted
# 2511      FGFR1   hsa-miR-106a-3p  ProstateCancer(OICR,CA)       Disrupted
# 2549      FGFR1   hsa-miR-4708-5p    LiverCancer(RIKEN,JP)       Disrupted
# 2569      FGFR1     hsa-miR-1273f    LiverCancer(RIKEN,JP)       Disrupted
# 2773      FGFR1      hsa-miR-1280      LiverCancer(NCC,JP)       Disrupted
# 2813      FGFR1   hsa-miR-4731-3p      LiverCancer(NCC,JP)       Disrupted
# 2947      FGFR1    hsa-miR-377-3p      LiverCancer(NCC,JP)       Disrupted
# 3143      FGFR1      hsa-miR-4476           Leukemia/T-ALL       Disrupted
# 3144      FGFR1  hsa-miR-509-3-5p           Leukemia/T-ALL       Disrupted
# 3147      FGFR1    hsa-miR-509-5p           Leukemia/T-ALL       Disrupted
# 3158      FGFR1      hsa-miR-4519           Leukemia/T-ALL       Disrupted
# 3159      FGFR1    hsa-miR-18a-3p           Leukemia/T-ALL       Disrupted
# 3163      FGFR1    hsa-miR-141-3p           Leukemia/T-ALL       Disrupted
# 3219      FGFR1   hsa-miR-5197-3p           Leukemia/T-ALL       Disrupted
# 3390      FGFR1      hsa-miR-1184           Leukemia/T-ALL       Disrupted
# 3391      FGFR1      hsa-miR-1301           Leukemia/T-ALL       Disrupted
# 3392      FGFR1   hsa-miR-200a-3p           Leukemia/T-ALL       Disrupted
# 3393      FGFR1      hsa-miR-5047           Leukemia/T-ALL       Disrupted
# 3440      FGFR1      hsa-miR-4274           Leukemia/T-ALL       Disrupted
# 3457      FGFR1    hsa-miR-324-3p           Leukemia/T-ALL       Disrupted
# 3493      FGFR1      hsa-miR-4418           Leukemia/T-ALL       Disrupted
# 3509      FGFR1  hsa-miR-4524a-5p           Leukemia/T-ALL       Disrupted
# 3527      FGFR1  hsa-miR-4524b-5p           Leukemia/T-ALL       Disrupted
# 3559      FGFR1   hsa-miR-374b-3p           Leukemia/T-ALL       Disrupted
# 3584      FGFR1      hsa-miR-3185           Leukemia/T-ALL       Disrupted
# 3604      FGFR1       hsa-miR-650           Leukemia/T-ALL       Disrupted
# 3621      FGFR1      hsa-miR-3612           Leukemia/T-ALL       Disrupted

# %%
len(ao)
# Out:
# 1847

# %%
ao3 = ao[ao["Targetsiteclass"] == "Created"]
ao3.head()
# Out:
#    Genesymbol            miRNA Cancertype Targetsiteclass
# 21       AKT1     hsa-miR-4422   Prostate         Created
# 22       AKT1     hsa-miR-4422   Prostate         Created
# 23       AKT1     hsa-miR-4422   Prostate         Created
# 28   ARHGAP26  hsa-miR-4787-5p   Prostate         Created
# 29   ARHGAP26  hsa-miR-4787-5p   Prostate         Created

# %%
len(ao3)
# Out:
# 1918

# %%
ao3nd = ao3.drop_duplicates()

# %%
len(ao3nd)
# Out:
# 820

# %%
ao3nd[["miRNA", "Genesymbol"]].to_csv("createdoncs2.txt", sep="\t")

# %%
H = nx.read_edgelist("C:/Users/jtso/My Documents/Cancer miRNA rewiring project/createdoncs2.txt", delimiter="\t", create_using=nx.DiGraph())
H.remove_edge("Genesymbol", "miRNA")  # remove the header line

# %%
ao3nd[ao3nd["Genesymbol"] == "RAB8A"]
# Out:
# Empty DataFrame
# Columns: [Genesymbol, miRNA, Cancertype, Targetsiteclass]
# Index: []

# %%
ao3nd
# Out:
#      Genesymbol              miRNA  \
# 21         AKT1       hsa-miR-4422
# 28     ARHGAP26    hsa-miR-4787-5p
# 32        BCAS3       hsa-miR-4530
# 38        BCAS3     hsa-miR-361-3p
# 42          BCR        hsa-miR-558
# 44          BCR   hsa-miR-3150a-3p
# 46          BCR        hsa-miR-939
# 48          BCR       hsa-miR-3175
# 58          BCR        hsa-miR-920
# 60          BCR       hsa-miR-4300
# 62          BCR    hsa-miR-5591-5p
# 64          BCR    hsa-miR-4667-5p
# 65          BCR    hsa-miR-4700-5p
# 70         FLI1   hsa-miR-4520a-5p
# 71         FLI1   hsa-miR-4520b-5p
# 78        MYH11        hsa-miR-573
# 80        MYH11    hsa-miR-3616-5p
# 82        MYH11    hsa-miR-4795-5p
# 83        MYH11        hsa-miR-595
# 97       ZNF320        hsa-miR-137
# 98       ZNF320        hsa-miR-656
# 101      ZNF320     hsa-miR-126-5p
# 102      ZNF320    hsa-miR-4795-3p
# 103      ZNF320    hsa-let-7f-2-3p
# 104      ZNF320  hsa-miR-1185-1-3p
# 105      ZNF320  hsa-miR-1185-2-3p
# 107        AFF4      hsa-miR-548an
# 110         AXL       hsa-miR-9-5p
# 114      BCL11A       hsa-miR-5680
# 118        CRKL    hsa-miR-644b-5p
# ...         ...                ...
# 3335      FGFR1    hsa-miR-4482-5p
# 3347       NRAS    hsa-miR-3681-3p
# 3348       NRAS       hsa-miR-4672
# 3350        RET       hsa-miR-4526
# 3351      FGFR2       hsa-miR-5696
# 3352      FGFR2     hsa-miR-664-3p
# 3364        VHL     hsa-miR-501-5p
# 3383     PIK3R1     hsa-miR-582-3p
# 3387       PIM1       hsa-miR-4262
# 3389       EGFR    hsa-miR-130a-5p
# 3458      FGFR1    hsa-miR-4684-5p
# 3598      FGFR3        hsa-miR-297
# 3601       PIM1    hsa-miR-181c-5p
# 3613       EGFR     hsa-miR-205-3p
# 3670       GNAS        hsa-miR-596
# 3675       ELF4       hsa-miR-4283
# 3677       ELF4       hsa-miR-4489
# 3692      WHSC1        hsa-miR-711
# 3711       MXI1    hsa-miR-1271-3p
# 3712       MXI1    hsa-miR-1909-5p
# 3713       MXI1     hsa-miR-33b-3p
# 3714       MXI1    hsa-miR-4693-3p
# 3716       MXI1     hsa-miR-515-3p
# 3717       MXI1    hsa-miR-519e-3p
# 3718       MXI1  hsa-miR-550a-3-5p
# 3719       MXI1    hsa-miR-550a-5p
# 3741       AFF4     hsa-miR-570-3p
# 3742       AFF4    hsa-miR-1225-3p
# 3744       AFF4       hsa-miR-3943
# 3749       KRAS       hsa-miR-4775
#
#                                        Cancertype Targetsiteclass
# 21                                       Prostate         Created
# 28                                       Prostate         Created
# 32                                       Melanoma         Created
# 38                                       Melanoma         Created
# 42                                       Melanoma         Created
# 44                                       Melanoma         Created
# 46                                       Melanoma         Created
# 48                                       Melanoma         Created
# 58                                       Melanoma         Created
# 60                                       Melanoma         Created
# 62                                       Melanoma         Created
# 64                                       Melanoma         Created
# 65                                       Melanoma         Created
# 70                                           Lung         Created
# 71                                           Lung         Created
# 78                                       Prostate         Created
# 80                                       Prostate         Created
# 82                                       Prostate         Created
# 83                                       Prostate         Created
# 97                                       Melanoma         Created
# 98                                       Melanoma         Created
# 101                                      Melanoma         Created
# 102                                      Melanoma         Created
# 103                                          Lung         Created
# 104                                          Lung         Created
# 105                                          Lung         Created
# 107                                 Breast Cancer         Created
# 110                                 Breast Cancer         Created
# 114                                 Breast Cancer         Created
# 118                                 Breast Cancer         Created
# ...                                           ...             ...
# 3335                               Leukemia/T-ALL         Created
# 3347                               Leukemia/T-ALL         Created
# 3348                               Leukemia/T-ALL         Created
# 3350                               Leukemia/T-ALL         Created
# 3351                               Leukemia/T-ALL         Created
# 3352                               Leukemia/T-ALL         Created
# 3364                               Leukemia/T-ALL         Created
# 3383                               Leukemia/T-ALL         Created
# 3387                               Leukemia/T-ALL         Created
# 3389                               Leukemia/T-ALL         Created
# 3458                               Leukemia/T-ALL         Created
# 3598                               Leukemia/T-ALL         Created
# 3601                               Leukemia/T-ALL         Created
# 3613                               Leukemia/T-ALL         Created
# 3670  UterineCorpusEndometrioidCarcinoma(TCGA,US)         Created
# 3675                          LiverCancer(NCC,JP)         Created
# 3677                          LiverCancer(NCC,JP)         Created
# 3692                 ColonAdenocarcinoma(TCGA,US)         Created
# 3711                        LiverCancer(RIKEN,JP)         Created
# 3712                        LiverCancer(RIKEN,JP)         Created
# 3713                        LiverCancer(RIKEN,JP)         Created
# 3714                        LiverCancer(RIKEN,JP)         Created
# 3716                        LiverCancer(RIKEN,JP)         Created
# 3717                        LiverCancer(RIKEN,JP)         Created
# 3718                        LiverCancer(RIKEN,JP)         Created
# 3719                        LiverCancer(RIKEN,JP)         Created
# 3741                        LiverCancer(RIKEN,JP)         Created
# 3742                        LiverCancer(RIKEN,JP)         Created
# 3744                        LiverCancer(RIKEN,JP)         Created
# 3749             BreastInvasiveCarcinoma(TCGA,US)         Created
#
# [820 rows x 4 columns]

# %%
from collections import Counter
d2 = {}
count = 0
for idx,row in ao3nd.iterrows():
    count += 1
    print count, "\r",
    d2[row["Genesymbol"]] = []
for idx,row in ao3nd.iterrows():
    if row["Cancertype"] in d2[row["Genesymbol"]]:
        continue
    d2[row["Genesymbol"]].append(row["Cancertype"])
d2
# Out:
# {'ABL2': ['Medulloblastoma',
#   'LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)'],
#  'AFF1': ['LiverCancer(NCC,JP)'],
#  'AFF4': ['Breast Cancer', 'LiverCancer(RIKEN,JP)', 'LiverCancer(NCC,JP)'],
#  'AKAP13': ['LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)'],
#  'AKT1': ['Prostate'],
#  'AKT2': ['ProstateCancer(OICR,CA)',
#   'LiverCancer(NCC,JP)',
#   'LiverCancer(RIKEN,JP)'],
#  'ARAF': ['LiverCancer(NCC,JP)'],
#  'ARHGAP26': ['Prostate', 'ProstateCancer(OICR,CA)'],
#  'ARHGEF12': ['BreastCarcinoma(WTSI,UK)'],
#  'AURKA': ['BreastCarcinoma(WTSI,UK)'],
#  'AXL': ['Breast Cancer'],
#  'BCAS3': ['Melanoma', 'LiverCancer(NCC,JP)'],
#  'BCAS4': ['LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)'],
#  'BCL11A': ['Breast Cancer', 'LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)'],
#  'BCL2': ['LiverCancer(NCC,JP)', 'ProstateCancer(OICR,CA)'],
#  'BCL6': ['LiverCancer(RIKEN,JP)'],
#  'BCR': ['Melanoma'],
#  'BTG1': ['LiverCancer(RIKEN,JP)'],
#  'CARS': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'CBL': ['ProstateCancer(OICR,CA)', 'LiverCancer(NCC,JP)'],
#  'CCND2': ['LiverCancer(RIKEN,JP)'],
#  'CDKN1B': ['LiverCancer(NCC,JP)'],
#  'CREB3L2': ['LiverCancer(RIKEN,JP)'],
#  'CRK': ['LiverCancer(NCC,JP)'],
#  'CRKL': ['Breast Cancer', 'LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)'],
#  'DEK': ['LiverCancer(NCC,JP)'],
#  'EGFR': ['Myeloid leukemia', 'LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'ELF4': ['LiverCancer(NCC,JP)'],
#  'ELL': ['LiverCancer(NCC,JP)'],
#  'ENTPD5': ['LiverCancer(NCC,JP)'],
#  'EPS15': ['LiverCancer(RIKEN,JP)'],
#  'ERBB3': ['LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)',
#   'ProstateCancer(OICR,CA)'],
#  'ERBB4': ['Acute myeloid leukemia',
#   'Colorectal adenocarcinoma',
#   'LiverCancer(RIKEN,JP)'],
#  'ERG': ['Hypodiploid_ALL'],
#  'ETV6': ['LiverCancer(RIKEN,JP)'],
#  'FGF5': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)'],
#  'FGFR1': ['Medulloblastoma',
#   'LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)',
#   'Leukemia/T-ALL'],
#  'FGFR2': ['Colorectal adenocarcinoma',
#   'GastricCancer(CCGC,CN)',
#   'Leukemia/T-ALL'],
#  'FGFR3': ['Leukemia/T-ALL'],
#  'FLI1': ['Lung'],
#  'FOXO1': ['LiverCancer(NCC,JP)'],
#  'FOXO4': ['LiverCancer(NCC,JP)'],
#  'FURIN': ['LiverCancer(RIKEN,JP)'],
#  'GAS7': ['LiverCancer(NCC,JP)', 'ProstateCancer(OICR,CA)'],
#  'GFI1': ['LiverCancer(NCC,JP)'],
#  'GNAS': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'BladderUrothelialCarcinoma(TCGA,US)',
#   'LiverCancer(NCC,JP)'],
#  'HCK': ['LiverCancer(NCC,JP)'],
#  'HLF': ['LiverCancer(NCC,JP)'],
#  'HMGA2': ['Breast Cancer', 'LiverCancer(RIKEN,JP)'],
#  'HOPX': ['LiverCancer(NCC,JP)'],
#  'HOXA9': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'HRAS': ['LiverCancer(NCC,JP)', 'Leukemia/T-ALL'],
#  'ING3': ['LiverCancer(NCC,JP)'],
#  'JAK2': ['LiverCancer(NCC,JP)'],
#  'JUNB': ['Breast Cancer'],
#  'KAT5': ['LiverCancer(RIKEN,JP)'],
#  'KAT6A': ['Acute myeloid leukemia',
#   'BreastCarcinoma(WTSI,UK)',
#   'Hypodiploid_ALL'],
#  'KDSR': ['ProstateCancer(OICR,CA)'],
#  'KIT': ['LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'KRAS': ['LiverCancer(RIKEN,JP)',
#   'ProstateCancer(OICR,CA)',
#   'BreastInvasiveCarcinoma(TCGA,US)'],
#  'LCK': ['Leukemia/T-ALL'],
#  'LITAF': ['ProstateCancer(OICR,CA)',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'MAF': ['LiverCancer(NCC,JP)', 'LiverCancer(RIKEN,JP)'],
#  'MAFB': ['LiverCancer(RIKEN,JP)'],
#  'MAL': ['T-cell ALL'],
#  'MCF2': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'MDM2': ['ProstateCancer(OICR,CA)', 'LiverCancer(RIKEN,JP)'],
#  'MECOM': ['LiverCancer(RIKEN,JP)'],
#  'MET': ['ProstateCancer(OICR,CA)'],
#  'MLL': ['LiverCancer(RIKEN,JP)'],
#  'MLLT6': ['Colorectal adenocarcinoma',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)'],
#  'MXI1': ['LiverCancer(RIKEN,JP)'],
#  'MYH11': ['Prostate'],
#  'NET1': ['LiverCancer(RIKEN,JP)'],
#  'NR4A3': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'NRAS': ['ProstateCancer(OICR,CA)', 'Leukemia/T-ALL'],
#  'PAK7': ['LiverCancer(RIKEN,JP)', 'Pancreatic'],
#  'PATZ1': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'PAX3': ['Medulloblastoma',
#   'UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'BladderUrothelialCarcinoma(TCGA,US)'],
#  'PAX5': ['LiverCancer(RIKEN,JP)'],
#  'PAX7': ['T-cell ALL', 'LiverCancer(RIKEN,JP)'],
#  'PBX1': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)'],
#  'PBX3': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'PCM1': ['ProstateCancer(OICR,CA)'],
#  'PDGFB': ['BreastCarcinoma(WTSI,UK)'],
#  'PDGFD': ['LiverCancer(RIKEN,JP)'],
#  'PDGFRB': ['LiverCancer(NCC,JP)'],
#  'PICALM': ['Colorectal adenocarcinoma', 'ProstateCancer(OICR,CA)'],
#  'PIK3R1': ['LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'PIM1': ['Leukemia/T-ALL'],
#  'PLAG1': ['LiverCancer(RIKEN,JP)'],
#  'PML': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'LiverCancer(NCC,JP)',
#   'ProstateCancer(OICR,CA)'],
#  'PRKCA': ['Hypodiploid_ALL'],
#  'PSMD10': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'RAF1': ['ColonAdenocarcinoma(TCGA,US)'],
#  'RARA': ['LiverCancer(NCC,JP)'],
#  'RARB': ['LiverCancer(RIKEN,JP)'],
#  'REL': ['ProstateCancer(OICR,CA)'],
#  'RET': ['Leukemia/T-ALL'],
#  'RNF213': ['ProstateCancer(OICR,CA)'],
#  'RUNX1': ['LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'RUNX1T1': ['LiverCancer(RIKEN,JP)', 'LiverCancer(NCC,JP)'],
#  'SKIL': ['LiverCancer(NCC,JP)'],
#  'SMAP2': ['Colorectal adenocarcinoma', 'LiverCancer(RIKEN,JP)'],
#  'SPECC1': ['ProstateCancer(OICR,CA)', 'LiverCancer(NCC,JP)'],
#  'SPI1': ['LiverCancer(NCC,JP)'],
#  'SRC': ['Medulloblastoma'],
#  'SS18': ['ProstateCancer(OICR,CA)'],
#  'STIL': ['ProstateCancer(OICR,CA)'],
#  'SUZ12': ['Colorectal adenocarcinoma', 'ProstateCancer(OICR,CA)'],
#  'SYK': ['ProstateCancer(OICR,CA)', 'LiverCancer(RIKEN,JP)'],
#  'TAL1': ['LiverCancer(RIKEN,JP)'],
#  'TCTA': ['Breast Cancer', 'LiverCancer(RIKEN,JP)', 'ProstateCancer(OICR,CA)'],
#  'TEF': ['LiverCancer(RIKEN,JP)'],
#  'THRB': ['LiverCancer(RIKEN,JP)'],
#  'TOP1': ['LiverCancer(RIKEN,JP)'],
#  'TPM3': ['LiverCancer(RIKEN,JP)', 'BladderUrothelialCarcinoma(TCGA,US)'],
#  'TPR': ['Hepatocellular carcinoma'],
#  'TTC23': ['LiverCancer(RIKEN,JP)'],
#  'USP28': ['ProstateCancer(OICR,CA)'],
#  'USP4': ['LiverCancer(RIKEN,JP)', 'ProstateCancer(OICR,CA)'],
#  'VAV2': ['LiverCancer(NCC,JP)'],
#  'VHL': ['LiverCancer(RIKEN,JP)', 'Leukemia/T-ALL'],
#  'WDR11': ['GastricCancer(CCGC,CN)'],
#  'WHSC1': ['LiverCancer(NCC,JP)',
#   'ColonAdenocarcinoma(TCGA,US)',
#   'LiverCancer(RIKEN,JP)'],
#  'WISP1': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)',
#   'BladderUrothelialCarcinoma(TCGA,US)'],
#  'WNT1': ['LiverCancer(RIKEN,JP)'],
#  'WNT5A': ['UterineCorpusEndometrioidCarcinoma(TCGA,US)'],
#  'WWTR1': ['LiverCancer(NCC,JP)'],
#  'YAP1': ['LiverCancer(RIKEN,JP)'],
#  'ZFYVE19': ['Colorectal adenocarcinoma'],
#  'ZNF320': ['Melanoma',
#   'Lung',
#   'ProstateCancer(OICR,CA)',
#   'LiverCancer(RIKEN,JP)',
#   'LiverCancer(NCC,JP)']}

# %%
for a,b in d2.items():
    d2[a] = len(d2[a])
    
d2
# Out:
# {'ABL2': 3,
#  'AFF1': 1,
#  'AFF4': 3,
#  'AKAP13': 2,
#  'AKT1': 1,
#  'AKT2': 3,
#  'ARAF': 1,
#  'ARHGAP26': 2,
#  'ARHGEF12': 1,
#  'AURKA': 1,
#  'AXL': 1,
#  'BCAS3': 2,
#  'BCAS4': 2,
#  'BCL11A': 3,
#  'BCL2': 2,
#  'BCL6': 1,
#  'BCR': 1,
#  'BTG1': 1,
#  'CARS': 1,
#  'CBL': 2,
#  'CCND2': 1,
#  'CDKN1B': 1,
#  'CREB3L2': 1,
#  'CRK': 1,
#  'CRKL': 3,
#  'DEK': 1,
#  'EGFR': 3,
#  'ELF4': 1,
#  'ELL': 1,
#  'ENTPD5': 1,
#  'EPS15': 1,
#  'ERBB3': 3,
#  'ERBB4': 3,
#  'ERG': 1,
#  'ETV6': 1,
#  'FGF5': 3,
#  'FGFR1': 4,
#  'FGFR2': 3,
#  'FGFR3': 1,
#  'FLI1': 1,
#  'FOXO1': 1,
#  'FOXO4': 1,
#  'FURIN': 1,
#  'GAS7': 2,
#  'GFI1': 1,
#  'GNAS': 3,
#  'HCK': 1,
#  'HLF': 1,
#  'HMGA2': 2,
#  'HOPX': 1,
#  'HOXA9': 1,
#  'HRAS': 2,
#  'ING3': 1,
#  'JAK2': 1,
#  'JUNB': 1,
#  'KAT5': 1,
#  'KAT6A': 3,
#  'KDSR': 1,
#  'KIT': 2,
#  'KRAS': 3,
#  'LCK': 1,
#  'LITAF': 2,
#  'MAF': 2,
#  'MAFB': 1,
#  'MAL': 1,
#  'MCF2': 1,
#  'MDM2': 2,
#  'MECOM': 1,
#  'MET': 1,
#  'MLL': 1,
#  'MLLT6': 3,
#  'MXI1': 1,
#  'MYH11': 1,
#  'NET1': 1,
#  'NR4A3': 1,
#  'NRAS': 2,
#  'PAK7': 2,
#  'PATZ1': 1,
#  'PAX3': 3,
#  'PAX5': 1,
#  'PAX7': 2,
#  'PBX1': 3,
#  'PBX3': 1,
#  'PCM1': 1,
#  'PDGFB': 1,
#  'PDGFD': 1,
#  'PDGFRB': 1,
#  'PICALM': 2,
#  'PIK3R1': 2,
#  'PIM1': 1,
#  'PLAG1': 1,
#  'PML': 3,
#  'PRKCA': 1,
#  'PSMD10': 1,
#  'RAF1': 1,
#  'RARA': 1,
#  'RARB': 1,
#  'REL': 1,
#  'RET': 1,
#  'RNF213': 1,
#  'RUNX1': 2,
#  'RUNX1T1': 2,
#  'SKIL': 1,
#  'SMAP2': 2,
#  'SPECC1': 2,
#  'SPI1': 1,
#  'SRC': 1,
#  'SS18': 1,
#  'STIL': 1,
#  'SUZ12': 2,
#  'SYK': 2,
#  'TAL1': 1,
#  'TCTA': 3,
#  'TEF': 1,
#  'THRB': 1,
#  'TOP1': 1,
#  'TPM3': 2,
#  'TPR': 1,
#  'TTC23': 1,
#  'USP28': 1,
#  'USP4': 2,
#  'VAV2': 1,
#  'VHL': 2,
#  'WDR11': 1,
#  'WHSC1': 3,
#  'WISP1': 2,
#  'WNT1': 1,
#  'WNT5A': 1,
#  'WWTR1': 1,
#  'YAP1': 1,
#  'ZFYVE19': 1,
#  'ZNF320': 5}

# %%
import operator
sorted_d2 = sorted(d2.items(), key=operator.itemgetter(1))

# %%
sorted_d2
# Out:
# [('PDGFRB', 1),
#  ('MCF2', 1),
#  ('AKT1', 1),
#  ('ARAF', 1),
#  ('USP28', 1),
#  ('MAFB', 1),
#  ('AXL', 1),
#  ('FURIN', 1),
#  ('RARA', 1),
#  ('ZFYVE19', 1),
#  ('THRB', 1),
#  ('ARHGEF12', 1),
#  ('FLI1', 1),
#  ('TPR', 1),
#  ('PATZ1', 1),
#  ('FGFR3', 1),
#  ('KAT5', 1),
#  ('MAL', 1),
#  ('RNF213', 1),
#  ('CCND2', 1),
#  ('PCM1', 1),
#  ('DEK', 1),
#  ('CRK', 1),
#  ('STIL', 1),
#  ('AFF1', 1),
#  ('JAK2', 1),
#  ('PAX5', 1),
#  ('RARB', 1),
#  ('HCK', 1),
#  ('ING3', 1),
#  ('KDSR', 1),
#  ('HOPX', 1),
#  ('VAV2', 1),
#  ('PSMD10', 1),
#  ('HLF', 1),
#  ('WNT5A', 1),
#  ('LCK', 1),
#  ('MYH11', 1),
#  ('RET', 1),
#  ('REL', 1),
#  ('RAF1', 1),
#  ('BCR', 1),
#  ('SPI1', 1),
#  ('BTG1', 1),
#  ('MECOM', 1),
#  ('TEF', 1),
#  ('CDKN1B', 1),
#  ('TTC23', 1),
#  ('SRC', 1),
#  ('TAL1', 1),
#  ('ELL', 1),
#  ('SS18', 1),
#  ('YAP1', 1),
#  ('WWTR1', 1),
#  ('WNT1', 1),
#  ('ETV6', 1),
#  ('MET', 1),
#  ('WDR11', 1),
#  ('HOXA9', 1),
#  ('JUNB', 1),
#  ('ENTPD5', 1),
#  ('FOXO1', 1),
#  ('ERG', 1),
#  ('TOP1', 1),
#  ('FOXO4', 1),
#  ('ELF4', 1),
#  ('EPS15', 1),
#  ('AURKA', 1),
#  ('CARS', 1),
#  ('PLAG1', 1),
#  ('NET1', 1),
#  ('PDGFB', 1),
#  ('PDGFD', 1),
#  ('PIM1', 1),
#  ('PRKCA', 1),
#  ('NR4A3', 1),
#  ('MLL', 1),
#  ('SKIL', 1),
#  ('PBX3', 1),
#  ('GFI1', 1),
#  ('MXI1', 1),
#  ('CREB3L2', 1),
#  ('BCL6', 1),
#  ('SMAP2', 2),
#  ('ARHGAP26', 2),
#  ('USP4', 2),
#  ('MDM2', 2),
#  ('SYK', 2),
#  ('LITAF', 2),
#  ('KIT', 2),
#  ('RUNX1', 2),
#  ('MAF', 2),
#  ('PAK7', 2),
#  ('HRAS', 2),
#  ('WISP1', 2),
#  ('PIK3R1', 2),
#  ('PAX7', 2),
#  ('CBL', 2),
#  ('GAS7', 2),
#  ('AKAP13', 2),
#  ('BCAS4', 2),
#  ('BCAS3', 2),
#  ('TPM3', 2),
#  ('HMGA2', 2),
#  ('SPECC1', 2),
#  ('VHL', 2),
#  ('RUNX1T1', 2),
#  ('NRAS', 2),
#  ('SUZ12', 2),
#  ('PICALM', 2),
#  ('BCL2', 2),
#  ('AFF4', 3),
#  ('CRKL', 3),
#  ('AKT2', 3),
#  ('KRAS', 3),
#  ('ERBB3', 3),
#  ('ERBB4', 3),
#  ('FGFR2', 3),
#  ('WHSC1', 3),
#  ('PAX3', 3),
#  ('FGF5', 3),
#  ('GNAS', 3),
#  ('TCTA', 3),
#  ('ABL2', 3),
#  ('PML', 3),
#  ('EGFR', 3),
#  ('BCL11A', 3),
#  ('MLLT6', 3),
#  ('PBX1', 3),
#  ('KAT6A', 3),
#  ('FGFR1', 4),
#  ('ZNF320', 5)]

# %%
genes= []
targets=[]
for idx,row in ao3nd[["Genesymbol", "miRNA"]].iterrows():
    if d2[row["Genesymbol"]] >= 4:
        genes.append(row["Genesymbol"])
        targets += H.neighbors(row["Genesymbol"])
h = H.subgraph(genes + targets)
colors = ['b' if n in genes else 'r' for n in h.nodes()]
figure(figsize=(25,25))
nx.draw(h, node_color=colors, alpha=.4, with_labels=True)

# %%
len(d2)
# Out:
# 132
